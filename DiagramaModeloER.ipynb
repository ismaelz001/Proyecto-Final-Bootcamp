# %% [markdown]
# """
# # 📊 Documentación de la Base de Datos - Proyecto E-commerce PC Componentes
#
# Este notebook documenta la arquitectura de la base de datos utilizada en el proyecto,
# explicando la utilidad de cada tabla y el significado de cada una de sus columnas.
# """
#
#
#
# """
# ## 📌 Diagrama Entidad-Relación (MER)
# El modelo Entidad-Relación define la estructura de la base de datos y las relaciones entre sus tablas.
# """
#
# """
# ## 📋 Descripción de las Tablas
# ### 🔹 Tabla `categorias_portatiles`
# Almacena las diferentes categorías de portátiles disponibles en el catálogo.
#
# **Columnas:**
# - `categoria_id (PK)`: Identificador único de la categoría.
# - `categoria_nombre`: Nombre de la categoría.
# - `url`: Enlace a la página de la categoría en la web.
# """
#
# """
# ### 🔹 Tabla `productos_portatiles`
# Almacena la información de los productos portátiles.
#
# **Columnas:**
# - `producto_id (PK)`: Identificador único del portátil.
# - `timestamp`: Fecha y hora de la extracción de datos.
# - `nombre`: Nombre del producto.
# - `url`: Enlace al producto en la web.
# - `precio`: Precio actual del producto.
# - `precio_tachado`: Precio anterior del producto si está en oferta.
# - `rating`: Calificación promedio de los usuarios.
# - `opiniones`: Número de opiniones registradas.
# - `categoria_id (FK)`: Relación con la tabla `categorias_portatiles`.
# - `descuento_porcentaje`: Descuento aplicado en el precio del producto.
# - `marca`: Marca del portátil.
# - `cluster (FK)`: Etiqueta del cluster asignado tras el análisis de clustering.
# """
#
# """
# ### 🔹 Tabla `caracteristicas_portatiles`
# Esta tabla almacena las especificaciones técnicas de cada portátil.
#
# **Columnas:**
# - `producto_id (FK)`: Identificador del producto (relación 1:1 con `productos_portatiles`).
# - `Processor_Cores`: Número de núcleos del procesador.
# - `Processor_Speed`: Velocidad del procesador en GHz.
# - `RAM_Gbs`: Memoria RAM en GB.
# - `Storage_Gbs`: Capacidad de almacenamiento en GB.
# - `Display_Inches`: Tamaño de la pantalla en pulgadas.
# - `GPU_Model`: Modelo de la tarjeta gráfica.
# - `USB_Ports`: Número de puertos USB.
# - `Operating_System`: Sistema operativo instalado.
# - `Weight`: Peso del portátil en kg.
# - `Battery_mAh`: Capacidad de la batería en mAh.
# """
#
# """
# ## 🔎 Conclusión
# El diseño de esta base de datos facilita la gestión y el análisis de los productos portátiles,
# permitiendo segmentar y categorizar los dispositivos con base en sus especificaciones
# y las opiniones de los clientes.
# """

# %%
import pandas as pd
import matplotlib.pyplot as plt
import IPython.display as display

# Mostrar imagen del diagrama MER dentro del notebook
image_path = "src/pages/diagramaMER.png"  # Asegúrate de que el archivo está en la misma carpeta del notebook
display.display(display.Image(image_path))
