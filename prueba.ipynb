# %%
import pandas as pd

# %%
# Cargar el archivo CSV en un DataFrame
df2 = pd.read_csv('data/categoriasPC.csv')

# Mostrar el DataFrame
df2.head(25)
# Out:
#    Unnamed: 0                         nombre  \
# 0           0                   Capturadoras
# 1           1  Kits de refrigeración líquida
# 2           2                        Samsung
# 3           3                        Corsair
# 4           4                         NVIDIA
# 5           5                       Gigabyte
# 6           6                   Discos duros
# 7           7                     Grabadoras
# 8           8              Tarjetas gráficas
# 9           9                            MSI
#
#                                                  url
# 0         https://www.pccomponentes.com/capturadoras
# 1  https://www.pccomponentes.com/refrigeracion-li...
# 2  https://www.pccomponentes.com/samsung?categori...
# 3        https://www.pccomponentes.com/corsair-store
# 4   https://www.pccomponentes.com/nvidia-brand-store
# 5  https://www.pccomponentes.com/gigabyte?categor...
# 6         https://www.pccomponentes.com/discos-duros
# 7  https://www.pccomponentes.com/grabadoras-dvd-b...
# 8    https://www.pccomponentes.com/tarjetas-graficas
# 9  https://www.pccomponentes.com/msi?categories=c...

# %%
# Cargar el archivo CSV en un DataFrame
df3 = pd.read_csv('data/categoriasPortatiles.csv')

# Mostrar el DataFrame
df3.head(25)
# Out:
#    Unnamed: 0                          nombre  \
# 0           0                        Mochilas
# 1           1                  PC con Windows
# 2           2                      Portátiles
# 3           3                              HP
# 4           4                              HP
# 5           5                          Lenovo
# 6           6          PC sobremesa por marca
# 7           7                          Alurin
# 8           8                           PcCom
# 9           9  Portátiles 2 en 1 convertibles
#
#                                                  url
# 0  https://www.pccomponentes.com/accesorios-porta...
# 1    https://www.pccomponentes.com/sobremesa/windows
# 2           https://www.pccomponentes.com/portatiles
# 3          https://www.pccomponentes.com/portatil-hp
# 4         https://www.pccomponentes.com/sobremesa/hp
# 5   https://www.pccomponentes.com/ordenadores-lenovo
# 6            https://www.pccomponentes.com/sobremesa
# 7    https://www.pccomponentes.com/portatiles/alurin
# 8  https://www.pccomponentes.com/sobremesa/pccom-...
# 9  https://www.pccomponentes.com/portatiles/2-en-...

# %%
# Cargar el archivo CSV en un DataFrame
df = pd.read_csv('data/productos_componentes_pc.csv')

# Mostrar el DataFrame
df.head()
# Out:
#                                      id            timestamp  \
# 0  f5491490-a366-4359-9b37-2f6bffb82f63  2025-02-12 18:34:29
# 1  b86a3210-721e-47b8-9a3d-9a45ce07bc18  2025-02-12 18:34:40
# 2  a1afa2a9-53d2-44e8-a050-ded7ed42515a  2025-02-12 18:34:40
# 3  917a744e-70af-41f8-8cbd-e5eb189218b3  2025-02-12 18:34:40
# 4  4cc882e5-88a8-4e90-a705-252e22e53f6d  2025-02-12 18:34:40
#
#                                               nombre  \
# 0  Asus ZenDrive U8M Grabadora de DVD Portátil US...
# 1  Creative Sound BlasterX AE-5 Plus Tarjeta de S...
# 2  Creative Sound Blaster Play! 3 Tarjeta de Soni...
# 3  Creative Sound Blaster Z SE Tarjeta de Sonido ...
# 4  Creative Sound Blaster Play! 4 Tarjeta de Soni...
#
#                                                  url   precio precio_tachado  \
# 0  https://www.pccomponentes.com/asus-zendrive-u8...   53,55€            NaN
# 1  https://www.pccomponentes.com/creative-sound-b...  104,99€            NaN
# 2  https://www.pccomponentes.com/creative-sound-b...   21,95€            NaN
# 3  https://www.pccomponentes.com/creative-sound-b...   84,99€            NaN
# 4  https://www.pccomponentes.com/creative-sound-b...   19,37€            NaN
#
#   rating      opiniones           categoria
# 0  4,2/5    6 opiniones          Grabadoras
# 1  4,5/5   77 opiniones  Tarjetas de sonido
# 2  4,6/5  237 opiniones  Tarjetas de sonido
# 3  4,7/5  138 opiniones  Tarjetas de sonido
# 4    5/5    1 opiniones  Tarjetas de sonido

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 561 entries, 0 to 560
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   id              561 non-null    object
#  1   timestamp       561 non-null    object
#  2   nombre          561 non-null    object
#  3   url             561 non-null    object
#  4   precio          561 non-null    object
#  5   precio_tachado  170 non-null    object
#  6   rating          517 non-null    object
#  7   opiniones       517 non-null    object
#  8   categoria       561 non-null    object
# dtypes: object(9)
# memory usage: 39.6+ KB

# %%
df.isnull().sum()
# Out:
# id                  0
# timestamp           0
# nombre              0
# url                 0
# precio              0
# precio_tachado    391
# rating             44
# opiniones          44
# categoria           0
# dtype: int64

# %%
# Cargar el archivo CSV en un DataFrame
df1 = pd.read_csv('data/productosPortatil.csv')

# Mostrar el DataFrame
df1.head()
# Out:
#                                      id            timestamp  \
# 0  7c55f59e-e0a7-41eb-9628-8e06eb7ffb5e  2025-02-12 18:37:47
# 1  84e66993-471a-471d-b222-519e03c35728  2025-02-12 18:37:47
# 2  2bd4ed41-5164-42bf-8024-3161cc509dc8  2025-02-12 18:37:47
# 3  d2a086cd-88e9-4417-b708-1faf3c8207f3  2025-02-12 18:37:47
# 4  dab63850-16d7-45c7-aeba-971ca36e0f03  2025-02-12 18:37:47
#
#                                               nombre  \
# 0  Alurin Flow All in One Intel Core i5-12400/16G...
# 1  HP All-in-One 24-cr0015ns Intel Core i5-1335U/...
# 2  HP All-in-One 24-cr0018ns AMD Ryzen 5 7520U/16...
# 3  HP All-in-One 27-cr0011ns Intel Core i5-1335U/...
# 4  HP All-in-One 24-cr0006ns Intel Core i5-1335U/...
#
#                                                  url precio precio_tachado  \
# 0  https://www.pccomponentes.com/alurin-flow-all-...   815€            NaN
# 1  https://www.pccomponentes.com/hp-all-in-one-24...   649€           799€
# 2  https://www.pccomponentes.com/hp-all-in-one-24...   649€            NaN
# 3  https://www.pccomponentes.com/hp-all-in-one-27...   729€           849€
# 4  https://www.pccomponentes.com/hp-all-in-one-24...   749€        899,01€
#
#   rating      opiniones                    categoria
# 0  4,1/5   27 opiniones  PC todo en uno - All in One
# 1  4,6/5  121 opiniones  PC todo en uno - All in One
# 2  4,6/5  148 opiniones  PC todo en uno - All in One
# 3  4,7/5   29 opiniones  PC todo en uno - All in One
# 4  4,6/5  121 opiniones  PC todo en uno - All in One

# %%
df1.isnull().sum()
# Out:
# id                  0
# timestamp           0
# nombre              0
# url                 0
# precio              0
# precio_tachado    215
# rating             60
# opiniones          60
# categoria           0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 561 entries, 0 to 560
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   id              561 non-null    object
#  1   timestamp       561 non-null    object
#  2   nombre          561 non-null    object
#  3   url             561 non-null    object
#  4   precio          561 non-null    object
#  5   precio_tachado  170 non-null    object
#  6   rating          517 non-null    object
#  7   opiniones       517 non-null    object
#  8   categoria       561 non-null    object
# dtypes: object(9)
# memory usage: 39.6+ KB

# %%
# Cargar el archivo CSV en un DataFrame
df4 = pd.read_csv('data/caracteristicas_productos_portatil.csv')

# Mostrar el DataFrame
df4.head()
# Out:
#                                             Producto  \
# 0  Apple iMac 24 Apple M4 10 Núcleos/16GB/256GB S...
# 1  LG Gram 15ZD90S-G.AX75B Intel Evo Core Ultra 7...
# 2  Apple MacBook Air Apple M3 8 Núcleos/16GB/256G...
# 3  Apple MacBook Air Apple M3 8 Núcleos/24GB/512G...
# 4  Apple MacBook Air Apple M3 8 Núcleos/16GB/256G...
#
#                                     Característica_1  \
# 0  Diseñado para Apple Intelligence. Una nueva fo...
# 1  Pantalla con la máxima calidad de imagen: La n...
# 2  Potencia M3. Afilada al máximo. El MacBook Air...
# 3  Potencia M3. Afilada al máximo. El MacBook Air...
# 4  Potencia M3. Afilada al máximo. El MacBook Air...
#
#                                     Característica_2  \
# 0  Herramientas de Escritura. Apple Intelligence ...
# 1  Diseño resistente y compacto: LG gram cuenta c...
# 2  Diseño compacto. Como es superligero y mide po...
# 3  Diseño compacto. Como es superligero y mide po...
# 4  Diseño compacto. Como es superligero y mide po...
#
#                                     Característica_3  \
# 0  Búsquedas con lenguaje natural en la app Fotos...
# 1  Rendimiento y Conectividad: LG gram ha sido ce...
# 2  Haz más. Más rápido. La potencia de la CPU de ...
# 3  Haz más. Más rápido. La potencia de la CPU de ...
# 4  Haz más. Más rápido. La potencia de la CPU de ...
#
#                                     Característica_4  \
# 0  Image Playground. Crea imágenes originales y d...
# 1  Procesador Intel® Core™ Ultra 7 155H (con func...
# 2  Hasta 18 horas de autonomía1. Con autonomía pa...
# 3  Hasta 18 horas de autonomía1. Con autonomía pa...
# 4  Hasta 18 horas de autonomía1. Con autonomía pa...
#
#                                     Característica_5  \
# 0  Un gran poder conlleva una gran privacidad. Ap...
# 1  Memoria RAM 16 GB de RAM (LPDDR5 Doble Canal 6...
# 2  Una pantalla brillante. La pantalla Liquid Ret...
# 3  Una pantalla brillante. La pantalla Liquid Ret...
# 4  Brillante clarísimamente. La pantalla Liquid R...
#
#                                     Característica_6  \
# 0  Rendimiento. Potencia a primera vista. Con el ...
# 1  Disco duro Disco duro de memoria sólida de 512...
# 2  Entra por los ojos. Y los oídos. La cámara HD ...
# 3  Entra por los ojos. Y los oídos. La cámara HD ...
# 4  Entra por los ojos. Y los oídos. La cámara HD ...
#
#                                     Característica_7  \
# 0  Controlar los gastos familiares, llevar un neg...
# 1                           Almacenamiento óptico No
# 2  Apps que vuelan con el chip de Apple. Todas tu...
# 3  Apps que vuelan con el chip de Apple. Todas tu...
# 4  Apps que vuelan con el chip de Apple. Todas tu...
#
#                                     Característica_8  \
# 0  Hasta 6 veces más rápido que el iMac con Intel...
# 1  Display Pantalla LCD de 15,6" (39.6 cm), de br...
# 2  Conectividad total. El MacBook Air tiene dos p...
# 3  Conectividad total. El MacBook Air tiene dos p...
# 4  Conectividad total. El MacBook Air tiene dos p...
#
#                                     Característica_9  \
# 0  Hasta 2,1 veces más rápido que el iMac con M1 ...
# 1  Controlador gráfico Tarjeta gráfica Intel® Iri...
# 2  Si te gusta el iPhone, te encantará el Mac. El...
# 3  Si te gusta el iPhone, te encantará el Mac. El...
# 4  Si te gusta el iPhone, te encantará el Mac. El...
#
#                                    Característica_10  \
# 0  Hasta 4,5 veces más rápido que el todo en uno ...
# 1  Conectividad\n\nIntel Wi-Fi 6-E AX211 (Bandas ...
# 2  Chip\n\nChip M3 de Apple:\n\nCPU de 8 núcleos ...
# 3  Chip\n\nChip M3 de Apple:\n\nCPU de 8 núcleos ...
# 4  Tu dedo es tu llave maestra. Touch ID. Además ...
#
#                                    Característica_11  \
# 0  Pantalla. Qué gusto verte. La impresio­nante p...
# 1  Intel Wi-Fi 6-E AX211 (Bandas : 2'4GHz y 5GHz;...
# 2  Chip M3 de Apple:\n\nCPU de 8 núcleos (4 de re...
# 3  Chip M3 de Apple:\n\nCPU de 8 núcleos (4 de re...
# 4  Avisos legales:\n\nLa duración de la batería v...
#
#                                    Característica_12  \
# 0  El iMac también está disponible en una nueva o...
# 1    10/100/Gigabit con adaptador RJ45 (no incluido)
# 2  CPU de 8 núcleos (4 de rendimiento y 4 de efic...
# 3  CPU de 8 núcleos (4 de rendimiento y 4 de efic...
# 4  La duración de la batería varía en función de ...
#
#                                    Característica_13  \
# 0  Cámara. Micros. Altavoces. El escenario es tuy...
# 1                                      Bluetooth 5.3
# 2                                   GPU de 8 núcleos
# 3                                  GPU de 10 núcleos
# 4  La pantalla del MacBook Air de 15 pulgadas tie...
#
#                                    Característica_14  \
# 0  Las apps van que vuelan. El iMac viene con un ...
# 1  Cámara de portátil Webcam con sensor IR, FHD y...
# 2       Trazado de rayos por aceleración de hardware
# 3       Trazado de rayos por aceleración de hardware
# 4        Las apps están disponibles en el App Store.
#
#                                    Característica_15  \
# 0  iMac y iPhone. Equipazo. En el iMac tienes tod...
# 1                                       Micrófono Sí
# 2                        Neural Engine de 16 núcleos
# 3                        Neural Engine de 16 núcleos
# 4  La conexión Wi-Fi 6E está disponible en los pa...
#
#                                    Característica_16
# 0  Siente la atracción. El conector de corriente ...
# 1    Batería Batería de Polímero de Litio de 72 Wh *
# 2              100 GB/s de ancho de banda de memoria
# 3              100 GB/s de ancho de banda de memoria
# 4  Requiere una cuenta de iCloud y conexión a int...

# %%
# Cargar el archivo CSV en un DataFrame
df5 = pd.read_csv('data/caracteristicas_productos_componentes_pc.csv')

# Mostrar el DataFrame
df5.head()
# Out:
#                                             Producto  \
# 0  Nfortec ATRIA X Kit de Refrigeración Líquida 3...
# 1  Kingston FURY Beast DDR4 3200 MHz 128GB 4x32GB...
# 2  Asus TUF Gaming Capture Box-CU4K30 Capturadora...
# 3  Creative Sound Blaster Play! 4 Tarjeta de Soni...
# 4  Corsair HXi Series HX1500i 1500W 80 Plus Plati...
#
#                                     Característica_1  \
# 0  RENDIMIENTO ÓPTIMO: El diseño cuidado y perfil...
# 1               Diseño delgado del disipador térmico
# 2  Ofrece soporte de video passthrough de 4K hast...
# 3  Haga que su audio vaya más allá. Además de tod...
# 4  Cableado totalmente modular: Conecte solo los ...
#
#                                     Característica_2  \
# 0  EL SIGUIENTE PASO. Hemos diseñado un nuevo pat...
# 1  Actualización rentable de DDR4 de alto rendimi...
# 2  Ofrece transmisión de video en 4K hasta 30 fps...
# 3  Realmente fácil de llevar a todas partes. Extr...
# 4  Certificación Intel ATX 3.0: Cumple con el est...
#
#                                     Característica_3  \
# 0  LA BOMBA. Dentro del espejo infinito encontram...
# 1                           Compatible con Intel XMP
# 2  Dos conectores de 3.5 mm permiten la conexión ...
# 3  Mejor que el audio predeterminado. Después de ...
# 4  Ventilador de 140 mm con rodamiento dinámico f...
#
#                                     Característica_4  \
# 0  ACOPLAMIENTO ESPACIAL. ATRIA X incorpora una n...
# 1                           Compatible con AMD Ryzen
# 2  Certificado OBS Studio™ la compatibilidad gara...
# 3                                              Audio
# 4  El potente software CORSAIR iCUE: Cree curvas ...
#
#                                     Característica_5  \
# 0  VENTILADORES ARGB DE ALTO RENDIMIENTO. Los nue...
# 1  Velocidades de hasta 3733MHz y capacidades de ...
# 2  El diseño compacto del tamaño de la mitad de l...
# 3                                        Interno: No
# 4  Modo de ventilador Zero RPM: A cargas medias y...
#
#                                     Característica_6  \
# 0  Compatible con Intel LGA 17XX/12XX/115X/20xx/1366
# 1                Funcionalidad Plug & Play a 2666MHz
# 2  Admite video USB para una experiencia plug-and...
# 3                           Calidad de audio: 24 bit
# 4  Certificación 80 PLUS Platinum: Hasta un 92 % ...
#
#                                     Característica_7  \
# 0  Compatible con AMD: AM5/AM4/AM3/AM3+/AM2+/TR4/...
# 1                                   Capacidad 128 Go
# 2  La iluminación RGB en el exterior indica el es...
# 3      Línea de salida, relación señal/ruido: 110 dB
# 4  Condensadores electrolíticos 100 % japoneses a...
#
#                                     Característica_8  \
# 0  Radiador\n\nTamaño radiador: 392x121x27mm\nLon...
# 1                Frecuencia(s) memoria DDR4 3200 MHz
# 2                                  Detalles técnicos
# 3  Conversión de digital a analógico: 16/24-bit/1...
# 4  Compatibilidad con Modern Standby: Tiempos de ...
#
#                                     Característica_9  \
# 0                      Tamaño radiador: 392x121x27mm
# 1                          Norma JEDEC     PC4-25600
# 2                                        Interno: No
# 3  Impedancia recomendada para los auriculares: 1...
# 4  Plataforma totalmente digital: La topología LL...
#
#                                    Característica_10
# 0                           Longitud tubos: 395+-5mm
# 1                  Especificación memoria Unbuffered
# 2        Interfaz de host: USB 3.2 Gen 1 (3.1 Gen 1)
# 3                                        Interno: No
# 4  Garantía de diez años: Una garantía de funcion...
