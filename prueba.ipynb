# %%
import pandas as pd

# Cargar el archivo CSV en un DataFrame
df = pd.read_csv('data/productos_componentes_pc.csv')

# Mostrar el DataFrame
df.head()
# Out:
#                                      id            timestamp  \
# 0  670860ba-98cd-42d3-92fc-4d49b84e3154  2025-02-12 18:34:29
# 1  55ed97a7-c534-4a6e-afdb-200ac674989e  2025-02-12 18:34:29
# 2  14218b08-bb01-4565-9cfb-30d272c6de90  2025-02-12 18:34:29
# 3  935abc6f-ea2f-4ddb-8f45-407dd958750e  2025-02-12 18:34:29
# 4  17fa2b87-5e6f-4f3b-bcd8-4bfc26dc1741  2025-02-12 18:34:29
#
#                                               nombre  \
# 0  Asus SDRW-08D2S-U Lite Grabadora DVD Slim Exte...
# 1  Hitachi-LG GH24NSD5 Grabadora DVD-RW Interna N...
# 2  Verbatim 53504 Grabadora Externa CD/DVD USB 2....
# 3  Asus SDRW-08D2S-U Lite Grabadora DVD Slim Exte...
# 4                HP Grabadora Externa CD/DVD USB 2.0
#
#                                                  url  precio precio_tachado  \
# 0  https://www.pccomponentes.com/asus-sdrw-08d2s-...  32,98€         35,50€
# 1  https://www.pccomponentes.com/hitachi-lg-gh24n...  32,95€            NaN
# 2  https://www.pccomponentes.com/verbatim-53504-g...  27,99€            NaN
# 3  https://www.pccomponentes.com/asus-sdrw-08d2s-...  32,98€         35,50€
# 4  https://www.pccomponentes.com/hp-grabadora-ext...  49,99€            NaN
#
#   rating       opiniones   categoria
# 0  4,5/5  1403 opiniones  Grabadoras
# 1  4,5/5   522 opiniones  Grabadoras
# 2  4,4/5    50 opiniones  Grabadoras
# 3  4,5/5  1384 opiniones  Grabadoras
# 4  4,3/5   196 opiniones  Grabadoras

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 387 entries, 0 to 386
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   id              387 non-null    object
#  1   timestamp       387 non-null    object
#  2   nombre          387 non-null    object
#  3   url             387 non-null    object
#  4   precio          74 non-null     object
#  5   precio_tachado  68 non-null     object
#  6   rating          74 non-null     object
#  7   opiniones       74 non-null     object
#  8   categoria       387 non-null    object
# dtypes: object(9)
# memory usage: 27.3+ KB

# %%
df.isnull().sum()
# Out:
# id                   0
# timestamp            0
# nombre               0
# url                  1
# precio            1744
# precio_tachado    2463
# rating            1855
# opiniones         1855
# categoria            0
# dtype: int64

# %%
# Cargar el archivo CSV en un DataFrame
df1 = pd.read_csv('data/productosPortatil.csv')

# Mostrar el DataFrame
df1.head()
# Out:
#                                      id            timestamp  \
# 0  7c55f59e-e0a7-41eb-9628-8e06eb7ffb5e  2025-02-12 18:37:47
# 1  84e66993-471a-471d-b222-519e03c35728  2025-02-12 18:37:47
# 2  2bd4ed41-5164-42bf-8024-3161cc509dc8  2025-02-12 18:37:47
# 3  d2a086cd-88e9-4417-b708-1faf3c8207f3  2025-02-12 18:37:47
# 4  dab63850-16d7-45c7-aeba-971ca36e0f03  2025-02-12 18:37:47
#
#                                               nombre  \
# 0  Alurin Flow All in One Intel Core i5-12400/16G...
# 1  HP All-in-One 24-cr0015ns Intel Core i5-1335U/...
# 2  HP All-in-One 24-cr0018ns AMD Ryzen 5 7520U/16...
# 3  HP All-in-One 27-cr0011ns Intel Core i5-1335U/...
# 4  HP All-in-One 24-cr0006ns Intel Core i5-1335U/...
#
#                                                  url precio precio_tachado  \
# 0  https://www.pccomponentes.com/alurin-flow-all-...   815€            NaN
# 1  https://www.pccomponentes.com/hp-all-in-one-24...   649€           799€
# 2  https://www.pccomponentes.com/hp-all-in-one-24...   649€            NaN
# 3  https://www.pccomponentes.com/hp-all-in-one-27...   729€           849€
# 4  https://www.pccomponentes.com/hp-all-in-one-24...   749€        899,01€
#
#   rating      opiniones                    categoria
# 0  4,1/5   27 opiniones  PC todo en uno - All in One
# 1  4,6/5  121 opiniones  PC todo en uno - All in One
# 2  4,6/5  148 opiniones  PC todo en uno - All in One
# 3  4,7/5   29 opiniones  PC todo en uno - All in One
# 4  4,6/5  121 opiniones  PC todo en uno - All in One

# %%
df1.isnull().sum()
# Out:
# id                   0
# timestamp            0
# nombre               0
# url                  0
# precio            2640
# precio_tachado    3112
# rating            2782
# opiniones         2782
# categoria            0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2727 entries, 0 to 2726
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   id              2727 non-null   object
#  1   timestamp       2727 non-null   object
#  2   nombre          2727 non-null   object
#  3   url             2726 non-null   object
#  4   precio          983 non-null    object
#  5   precio_tachado  264 non-null    object
#  6   rating          872 non-null    object
#  7   opiniones       872 non-null    object
#  8   categoria       2727 non-null   object
# dtypes: object(9)
# memory usage: 191.9+ KB
