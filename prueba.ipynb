# %%
import pandas as pd

# %%
# Cargar el archivo CSV en un DataFrame
df2 = pd.read_csv('data/categoriasPC.csv')

# Mostrar el DataFrame
df2.head(25)
# Out:
#    Unnamed: 0                         nombre  \
# 0           0  Kits de refrigeración líquida
# 1           1                      Plus gold
# 2           2                      Barebones
# 3           3          Discos duros externos
# 4           4    Ventiladores suplementarios
#
#                                                  url
# 0  https://www.pccomponentes.com/refrigeracion-li...
# 1  https://www.pccomponentes.com/fuentes-alimenta...
# 2            https://www.pccomponentes.com/barebones
# 3  https://www.pccomponentes.com/discos-duros-ext...
# 4  https://www.pccomponentes.com/ventiladores-sup...

# %%
# Cargar el archivo CSV en un DataFrame
df3 = pd.read_csv('data/categoriasPortatiles.csv')

# Mostrar el DataFrame
df3.head(25)
# Out:
#    Unnamed: 0               nombre  \
# 0           0         PC sobremesa
# 1           1  Configurador de PCs
# 2           2                Intel
# 3           3      MacBook Pro/Air
# 4           4           Portátiles
#
#                                            url
# 0      https://www.pccomponentes.com/sobremesa
# 1   https://www.pccomponentes.com/configurador
# 2  https://www.pccomponentes.com/espacio-intel
# 3        https://www.pccomponentes.com/macbook
# 4     https://www.pccomponentes.com/portatiles

# %%
# Cargar el archivo CSV en un DataFrame
df = pd.read_csv('data/productos_componentes_pc.csv')

# Mostrar el DataFrame
df.head()
# Out:
#    producto_id            timestamp  \
# 0            1  2025-02-18 12:32:30
# 1            2  2025-02-18 12:32:30
# 2            3  2025-02-18 12:32:30
# 3            4  2025-02-18 12:32:30
# 4            5  2025-02-18 12:32:30
#
#                                               nombre  \
# 0  Tempest Liquid Cooler 360 ARGB Kit de Refriger...
# 1  Tempest Liquid Cooler 360 Kit de Refrigeración...
# 2  Forgeon Azoth 240 ARGB Kit de Refrigeración Lí...
# 3  Nfortec ATRIA X Kit de Refrigeración Líquida 3...
# 4  Corsair NAUTILUS 360 RS ARGB Kit Refrigeración...
#
#                                                  url   precio precio_tachado  \
# 0  https://www.pccomponentes.com/tempest-liquid-c...   76,99€         87,99€
# 1  https://www.pccomponentes.com/tempest-liquid-c...   68,99€         78,98€
# 2  https://www.pccomponentes.com/forgeon-azoth-24...   75,99€        149,99€
# 3  https://www.pccomponentes.com/nfortec-atria-x-...   94,99€            NaN
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   producto_id     200 non-null    int64
#  1   timestamp       200 non-null    object
#  2   nombre          200 non-null    object
#  3   url             200 non-null    object
#  4   precio          200 non-null    object
#  5   precio_tachado  55 non-null     object
#  6   rating          167 non-null    object
#  7   opiniones       167 non-null    object
#  8   categoria       200 non-null    object
# dtypes: int64(1), object(8)
# memory usage: 14.2+ KB

# %%
df.isnull().sum()
# Out:
# producto_id         0
# timestamp           0
# nombre              0
# url                 0
# precio              0
# precio_tachado    145
# rating             33
# opiniones          33
# categoria           0
# dtype: int64

# %%
# Cargar el archivo CSV en un DataFrame
df1 = pd.read_csv('data/productosPortatil.csv')

# Mostrar el DataFrame
df1.head()
# Out:
#    producto_id            timestamp  \
# 0            1  2025-02-18 12:31:30
# 1            2  2025-02-18 12:31:30
# 2            3  2025-02-18 12:31:30
# 3            4  2025-02-18 12:31:30
# 4            5  2025-02-18 12:31:30
#
#                                               nombre  \
# 0  PcCom Ready AMD Ryzen 7 5800X / 32GB / 1TB SSD...
# 1  PcCom Ready AMD Ryzen 7 5800X / 32GB / 1TB SSD...
# 2    PcCom Work Intel Core i5-12400 / 32GB / 1TB SSD
# 3  PcCom Ready AMD Ryzen 7 5800X / 32GB / 2TB SSD...
# 4  PcCom Ultimate Ryzen 7 9800X3D / 64GB / 2TB M....
#
#                                                  url  precio precio_tachado  \
# 0  https://www.pccomponentes.com/pccom-ready-amd-...  1.339€      1.760,25€
# 1  https://www.pccomponentes.com/pccom-ready-amd-...  1.229€      1.449,42€
# 2  https://www.pccomponentes.com/ordenador-sobrem...    509€        593,05€
# 3  https://www.pccomponentes.com/ordenador-sobrem...  1.429€      1.662,47€
# ...

# %%
df1.isnull().sum()
# Out:
# producto_id        0
# timestamp          0
# nombre             0
# url                0
# precio             0
# precio_tachado    21
# rating             3
# opiniones          3
# categoria          0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   producto_id     200 non-null    int64
#  1   timestamp       200 non-null    object
#  2   nombre          200 non-null    object
#  3   url             200 non-null    object
#  4   precio          200 non-null    object
#  5   precio_tachado  55 non-null     object
#  6   rating          167 non-null    object
#  7   opiniones       167 non-null    object
#  8   categoria       200 non-null    object
# dtypes: int64(1), object(8)
# memory usage: 14.2+ KB

# %%
# Cargar el archivo CSV en un DataFrame
df4 = pd.read_csv('data/caracteristicas_productos_portatil.csv')

# Mostrar el DataFrame
df4.head()
# Out:
#                                             Producto  \
# 0  PcCom Ready Intel Core i5 -12400F / 32GB / SSD...
# 1  Apple MacBook Pro Apple M4 Pro 14 Núcleos/24GB...
# 2  Apple MacBook Air Apple M3/16GB/512GB SSD/GPU ...
# 3  PcCom Imperial AMD Ryzen 7 7800X3D / 32GB / 2T...
# 4  PcCom Ready AMD Ryzen 7 5800X / 32GB / 1TB SSD...
#
#                                     Característica_1  \
# 0      Caja: Tempest Mirage RGB Mesh Torre ATX Negra
# 1  Lo dan todo. El MacBook Pro incorpora la gama ...
# 2  Potencia M3. Afilada al máximo. El MacBook Air...
# 3   Caja: Forgeon Arcanite ARGB Mesh Torre ATX Negra
# 4  Caja: Nfortec Krater X Cristal Templado USB 3....
#
#                                     Característica_2  \
# 0  Fuente de alimentación: Forgeon SI Series PSU ...
# 1  El MacBook Pro con M4 es hasta x3,4 más rápido...
# 2  Diseño compacto. Como es superligero y mide po...
# 3  Fuente de alimentación: Forgeon Bolt PSU 750W ...
# ...

# %%
df4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 17 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Producto           10 non-null     object
#  1   Característica_1   10 non-null     object
#  2   Característica_2   10 non-null     object
#  3   Característica_3   10 non-null     object
#  4   Característica_4   10 non-null     object
#  5   Característica_5   10 non-null     object
#  6   Característica_6   10 non-null     object
#  7   Característica_7   10 non-null     object
#  8   Característica_8   10 non-null     object
#  9   Característica_9   10 non-null     object
#  10  Característica_10  10 non-null     object
#  11  Característica_11  10 non-null     object
#  12  Característica_12  10 non-null     object
#  13  Característica_13  10 non-null     object
#  14  Característica_14  10 non-null     object
#  15  Característica_15  10 non-null     object
# ...

# %%
# Cargar el archivo CSV en un DataFrame
df5 = pd.read_csv('data/caracteristicas_productos_componentes_pc.csv')

# Mostrar el DataFrame
df5.head()
# Out:
#                                             Producto  \
# 0  NZXT Kraken Elite 360 RGB Kit de Refrigeración...
# 1  Forgeon Bolt PSU 1000W 80+ Gold Full Modular N...
# 2           SanDisk Extreme SSD Externo V2 4TB USB-C
# 3  Tempest Liquid Cooler 240 ARGB Kit Refrigeraci...
# 4  Forgeon Overmind Ventiladores Suplementarios I...
#
#                                     Característica_1  \
# 0  PERSONALIZACIÓN QUE DESTACA: Exhibe tu imagen ...
# 1                                     Ahorra espacio
# 2  Potente y portátil. Obtén el veloz rendimiento...
# 3  Enfría tu procesador: Olvida los viejos ventil...
# 4  Iluminación Atractiva: Los ventiladores Forgeo...
#
#                                     Característica_2  \
# 0  PANTALLA LCD CON GRAN ÁNGULO DE VISIÓN: Pantal...
# 1                                  Fácil instalación
# 2  Lo suficientemente resistente como para llevar...
# 3  Disfruta de su instalación: Referente a su ins...
# ...

# %%
df4 = pd.read_csv('data/caracteristicas_productos_portatil.csv')
print(df4.columns.tolist())  # Verifica los nombres exactos de las columnas
print(df4.head())  # Verifica si los datos están bien estructurados
# Out:
# ['Producto', 'Característica_1', 'Característica_2', 'Característica_3', 'Característica_4', 'Característica_5', 'Característica_6', 'Característica_7', 'Característica_8', 'Característica_9', 'Característica_10', 'Característica_11', 'Característica_12', 'Característica_13', 'Característica_14', 'Característica_15', 'Característica_16']
#                                             Producto  \
# 0  PcCom Ready Intel Core i5 -12400F / 32GB / SSD...
# 1  Apple MacBook Pro Apple M4 Pro 14 Núcleos/24GB...
# 2  Apple MacBook Air Apple M3/16GB/512GB SSD/GPU ...
# 3  PcCom Imperial AMD Ryzen 7 7800X3D / 32GB / 2T...
# 4  PcCom Ready AMD Ryzen 7 5800X / 32GB / 1TB SSD...
#
#                                     Característica_1  \
# 0      Caja: Tempest Mirage RGB Mesh Torre ATX Negra
# 1  Lo dan todo. El MacBook Pro incorpora la gama ...
# 2  Potencia M3. Afilada al máximo. El MacBook Air...
# 3   Caja: Forgeon Arcanite ARGB Mesh Torre ATX Negra
# ...

# %%
df5 = pd.read_csv('data/caracteristicas_productos_portatil.csv')
print(df5.columns.tolist())  # Verifica los nombres exactos de las columnas
print(df5.head())  # Verifica si los datos están bien estructurados
# Out:
# ['Producto', 'Característica_1', 'Característica_2', 'Característica_3', 'Característica_4', 'Característica_5', 'Característica_6', 'Característica_7', 'Característica_8', 'Característica_9', 'Característica_10', 'Característica_11', 'Característica_12', 'Característica_13', 'Característica_14', 'Característica_15', 'Característica_16']
#                                             Producto  \
# 0  PcCom Ready Intel Core i5 -12400F / 32GB / SSD...
# 1  Apple MacBook Pro Apple M4 Pro 14 Núcleos/24GB...
# 2  Apple MacBook Air Apple M3/16GB/512GB SSD/GPU ...
# 3  PcCom Imperial AMD Ryzen 7 7800X3D / 32GB / 2T...
# 4  PcCom Ready AMD Ryzen 7 5800X / 32GB / 1TB SSD...
#
#                                     Característica_1  \
# 0      Caja: Tempest Mirage RGB Mesh Torre ATX Negra
# 1  Lo dan todo. El MacBook Pro incorpora la gama ...
# 2  Potencia M3. Afilada al máximo. El MacBook Air...
# 3   Caja: Forgeon Arcanite ARGB Mesh Torre ATX Negra
# ...
