# %%
import pandas as pd

# %%
df = pd.read_csv('productosPortatil.csv')
df.head(10)
# Out:
#    producto_id            timestamp  \
# 0            1  2025-02-21 17:19:06
# 1            2  2025-02-21 17:19:06
# 2            3  2025-02-21 17:19:06
# 3            4  2025-02-21 17:19:06
# 4            5  2025-02-21 17:19:06
# 5            6  2025-02-21 17:19:06
# 6            7  2025-02-21 17:19:06
# 7            8  2025-02-21 17:19:06
# 8            9  2025-02-21 17:19:06
# 9           10  2025-02-21 17:19:06
#
#                                               nombre  \
# 0  Apple MacBook Pro Apple M4 Pro 14 Núcleos/24GB...
# 1  Acer Chromebook Plus 514 CB514-3H-R81B AMD Ryz...
# 2  Apple MacBook Air Apple M3 8 Núcleos/16GB/256G...
# 3  Apple MacBook Air Apple M3 8 Núcleos/24GB/512G...
# 4  Apple MacBook Air Apple M3 8 Núcleos/16GB/256G...
# 5  Apple MacBook Air Apple M3 8 Núcleos/24GB/512G...
# 6  Acer Gaming Nitro V 16 ANV16-41 AMD Ryzen 7 88...
# 7  Apple MacBook Air Apple M3 8 Núcleos/16GB/256G...
# 8  Apple MacBook Pro Apple M4 Pro 12 Núcleos/24GB...
# ...

# %%
df.describe()
# Out:
#        producto_id
# count   494.000000
# mean    247.500000
# std     142.749781
# min       1.000000
# 25%     124.250000
# 50%     247.500000
# 75%     370.750000
# max     494.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 494 entries, 0 to 493
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   producto_id     494 non-null    int64
#  1   timestamp       494 non-null    object
#  2   nombre          494 non-null    object
#  3   url             494 non-null    object
#  4   precio          494 non-null    object
#  5   precio_tachado  272 non-null    object
#  6   rating          382 non-null    object
#  7   opiniones       382 non-null    object
#  8   categoria       494 non-null    object
# dtypes: int64(1), object(8)
# memory usage: 34.9+ KB

# %%
df["nombre"] = df["nombre"].astype(str)
df["url"] = df["url"].astype(str)
df["categoria"] = df["categoria"].astype(str)

# %%
df['opiniones'] = df['opiniones'].str.replace(r'\D', '', regex=True)
df['opiniones'] = df['opiniones'].fillna(0)
df['opiniones'] = df['opiniones'].astype(int)
df.head()
# Out:
#    producto_id            timestamp  \
# 0            1  2025-02-21 17:19:06
# 1            2  2025-02-21 17:19:06
# 2            3  2025-02-21 17:19:06
# 3            4  2025-02-21 17:19:06
# 4            5  2025-02-21 17:19:06
#
#                                               nombre  \
# 0  Apple MacBook Pro Apple M4 Pro 14 Núcleos/24GB...
# 1  Acer Chromebook Plus 514 CB514-3H-R81B AMD Ryz...
# 2  Apple MacBook Air Apple M3 8 Núcleos/16GB/256G...
# 3  Apple MacBook Air Apple M3 8 Núcleos/24GB/512G...
# 4  Apple MacBook Air Apple M3 8 Núcleos/16GB/256G...
#
#                                                  url  precio precio_tachado  \
# 0  https://www.pccomponentes.com/portatil-apple-m...  2.688€         2.949€
# 1  https://www.pccomponentes.com/acer-chromebook-...    369€           499€
# 2  https://www.pccomponentes.com/portatil-apple-m...  1.489€         1.599€
# 3  https://www.pccomponentes.com/portatil-apple-m...  1.599€         1.759€
# ...

# %%
df['rating'] = df['rating'].str.replace(',', '.', regex=False)
df['rating'] = df['rating'].str.replace(r'/5', '', regex=True)
df['rating'] = df['rating'].astype(float)

# %%
df['precio'] = df['precio'].str.replace('.', '', regex=False)
df['precio'] = df['precio'].str.replace(',', '.', regex=False)
df['precio'] = df['precio'].str.replace(r'€', '', regex=True)
df['precio'] = df['precio'].astype(float)

# %%
df.head()
# Out:
#    producto_id            timestamp  \
# 0            1  2025-02-21 17:19:06
# 1            2  2025-02-21 17:19:06
# 2            3  2025-02-21 17:19:06
# 3            4  2025-02-21 17:19:06
# 4            5  2025-02-21 17:19:06
#
#                                               nombre  \
# 0  Apple MacBook Pro Apple M4 Pro 14 Núcleos/24GB...
# 1  Acer Chromebook Plus 514 CB514-3H-R81B AMD Ryz...
# 2  Apple MacBook Air Apple M3 8 Núcleos/16GB/256G...
# 3  Apple MacBook Air Apple M3 8 Núcleos/24GB/512G...
# 4  Apple MacBook Air Apple M3 8 Núcleos/16GB/256G...
#
#                                                  url  precio precio_tachado  \
# 0  https://www.pccomponentes.com/portatil-apple-m...  2688.0         2.949€
# 1  https://www.pccomponentes.com/acer-chromebook-...   369.0           499€
# 2  https://www.pccomponentes.com/portatil-apple-m...  1489.0         1.599€
# 3  https://www.pccomponentes.com/portatil-apple-m...  1599.0         1.759€
# ...

# %%
df['precio_tachado'] = df['precio_tachado'].str.replace('.', '', regex=False)
df['precio_tachado'] = df['precio_tachado'].str.replace(',', '.', regex=False)
df['precio_tachado'] = df['precio_tachado'].str.replace(r'€', '', regex=True)
# df['precio_tachado'] = df['precio_tachado'].fillna(df['precio'])
df['precio_tachado'] = df['precio_tachado'].astype(float)
df.head()
# Out:
#    producto_id            timestamp  \
# 0            1  2025-02-21 17:19:06
# 1            2  2025-02-21 17:19:06
# 2            3  2025-02-21 17:19:06
# 3            4  2025-02-21 17:19:06
# 4            5  2025-02-21 17:19:06
#
#                                               nombre  \
# 0  Apple MacBook Pro Apple M4 Pro 14 Núcleos/24GB...
# 1  Acer Chromebook Plus 514 CB514-3H-R81B AMD Ryz...
# 2  Apple MacBook Air Apple M3 8 Núcleos/16GB/256G...
# 3  Apple MacBook Air Apple M3 8 Núcleos/24GB/512G...
# 4  Apple MacBook Air Apple M3 8 Núcleos/16GB/256G...
#
#                                                  url  precio  precio_tachado  \
# 0  https://www.pccomponentes.com/portatil-apple-m...  2688.0          2949.0
# 1  https://www.pccomponentes.com/acer-chromebook-...   369.0           499.0
# 2  https://www.pccomponentes.com/portatil-apple-m...  1489.0          1599.0
# 3  https://www.pccomponentes.com/portatil-apple-m...  1599.0          1759.0
# ...

# %%
df['timestamp'] = pd.to_datetime(df['timestamp'])

# %%
df.head()
# Out:
#    producto_id           timestamp  \
# 0            1 2025-02-21 17:19:06
# 1            2 2025-02-21 17:19:06
# 2            3 2025-02-21 17:19:06
# 3            4 2025-02-21 17:19:06
# 4            5 2025-02-21 17:19:06
#
#                                               nombre  \
# 0  Apple MacBook Pro Apple M4 Pro 14 Núcleos/24GB...
# 1  Acer Chromebook Plus 514 CB514-3H-R81B AMD Ryz...
# 2  Apple MacBook Air Apple M3 8 Núcleos/16GB/256G...
# 3  Apple MacBook Air Apple M3 8 Núcleos/24GB/512G...
# 4  Apple MacBook Air Apple M3 8 Núcleos/16GB/256G...
#
#                                                  url  precio  precio_tachado  \
# 0  https://www.pccomponentes.com/portatil-apple-m...  2688.0          2949.0
# 1  https://www.pccomponentes.com/acer-chromebook-...   369.0           499.0
# 2  https://www.pccomponentes.com/portatil-apple-m...  1489.0          1599.0
# 3  https://www.pccomponentes.com/portatil-apple-m...  1599.0          1759.0
# ...

# %%
df.to_csv('productosPortatil-limpio.csv', index=False)

# %%
df1 = pd.read_csv('productos_componentes_pc.csv')
df1.head(10)
# Out:
#    producto_id            timestamp  \
# 0            1  2025-02-21 17:23:39
# 1            2  2025-02-21 17:23:39
# 2            3  2025-02-21 17:23:39
# 3            4  2025-02-21 17:23:39
# 4            5  2025-02-21 17:23:39
# 5            6  2025-02-21 17:23:39
# 6            7  2025-02-21 17:23:39
# 7            8  2025-02-21 17:23:39
# 8            9  2025-02-21 17:23:39
# 9           10  2025-02-21 17:23:39
#
#                                               nombre  \
# 0                               ASUS PRIME B760-PLUS
# 1                          ASUS TUF GAMING B650-PLUS
# 2                          ASUS PRIME B650-PLUS WIFI
# 3                         ASUS PRIME B550M-A WIFI II
# 4                        ASUS TUF GAMING B650-E WIFI
# 5  ASUS TUF Gaming GeForce RTX 5080 OC 16GB GDDR7...
# 6                            ASUS Prime B760-PLUS D4
# 7                     ASUS TUF GAMING B860-PLUS WIFI
# 8  ASUS Dual GeForce RTX 4060 EVO OC Edition 8GB ...
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 454 entries, 0 to 453
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   producto_id     454 non-null    int64
#  1   timestamp       454 non-null    object
#  2   nombre          454 non-null    object
#  3   url             454 non-null    object
#  4   precio          454 non-null    object
#  5   precio_tachado  169 non-null    object
#  6   rating          402 non-null    object
#  7   opiniones       402 non-null    object
#  8   categoria       454 non-null    object
# dtypes: int64(1), object(8)
# memory usage: 32.1+ KB

# %%
df1['opiniones'] = df1['opiniones'].str.replace(r'\D', '', regex=True)
df1['opiniones'] = df1['opiniones'].fillna(0)
df1['opiniones'] = df1['opiniones'].astype(int)
df1.head()
# Out:
#    producto_id            timestamp                       nombre  \
# 0            1  2025-02-21 17:23:39         ASUS PRIME B760-PLUS
# 1            2  2025-02-21 17:23:39    ASUS TUF GAMING B650-PLUS
# 2            3  2025-02-21 17:23:39    ASUS PRIME B650-PLUS WIFI
# 3            4  2025-02-21 17:23:39   ASUS PRIME B550M-A WIFI II
# 4            5  2025-02-21 17:23:39  ASUS TUF GAMING B650-E WIFI
#
#                                                  url   precio precio_tachado  \
# 0  https://www.pccomponentes.com/asus-prime-b760-...     134€        164,90€
# 1  https://www.pccomponentes.com/asus-tuf-gaming-...  213,15€        267,51€
# 2  https://www.pccomponentes.com/placa-base-asus-...  164,95€            NaN
# 3  https://www.pccomponentes.com/asus-prime-b550m...  123,75€        151,68€
# 4  https://www.pccomponentes.com/placa-base-asus-...  174,95€            NaN
#
#   rating  opiniones categoria
# 0  4,6/5        598      ASUS
# 1  4,5/5        953      ASUS
# ...

# %%
df1['rating'] = df1['rating'].str.replace(',', '.', regex=False)
df1['rating'] = df1['rating'].str.replace(r'/5', '', regex=True)
df1['rating'] = df1['rating'].astype(float)
df1.head()
# Out:
#    producto_id            timestamp                       nombre  \
# 0            1  2025-02-21 17:23:39         ASUS PRIME B760-PLUS
# 1            2  2025-02-21 17:23:39    ASUS TUF GAMING B650-PLUS
# 2            3  2025-02-21 17:23:39    ASUS PRIME B650-PLUS WIFI
# 3            4  2025-02-21 17:23:39   ASUS PRIME B550M-A WIFI II
# 4            5  2025-02-21 17:23:39  ASUS TUF GAMING B650-E WIFI
#
#                                                  url   precio precio_tachado  \
# 0  https://www.pccomponentes.com/asus-prime-b760-...     134€        164,90€
# 1  https://www.pccomponentes.com/asus-tuf-gaming-...  213,15€        267,51€
# 2  https://www.pccomponentes.com/placa-base-asus-...  164,95€            NaN
# 3  https://www.pccomponentes.com/asus-prime-b550m...  123,75€        151,68€
# 4  https://www.pccomponentes.com/placa-base-asus-...  174,95€            NaN
#
#    rating  opiniones categoria
# 0     4.6        598      ASUS
# 1     4.5        953      ASUS
# ...

# %%
df1['precio'] = df1['precio'].str.replace('.', '', regex=False)
df1['precio'] = df1['precio'].str.replace(',', '.', regex=False)
df1['precio'] = df1['precio'].str.replace(r'€', '', regex=True)
df1['precio'] = df1['precio'].astype(float)
df1.head()
# Out:
#    producto_id            timestamp                       nombre  \
# 0            1  2025-02-21 17:23:39         ASUS PRIME B760-PLUS
# 1            2  2025-02-21 17:23:39    ASUS TUF GAMING B650-PLUS
# 2            3  2025-02-21 17:23:39    ASUS PRIME B650-PLUS WIFI
# 3            4  2025-02-21 17:23:39   ASUS PRIME B550M-A WIFI II
# 4            5  2025-02-21 17:23:39  ASUS TUF GAMING B650-E WIFI
#
#                                                  url  precio precio_tachado  \
# 0  https://www.pccomponentes.com/asus-prime-b760-...  134.00        164,90€
# 1  https://www.pccomponentes.com/asus-tuf-gaming-...  213.15        267,51€
# 2  https://www.pccomponentes.com/placa-base-asus-...  164.95            NaN
# 3  https://www.pccomponentes.com/asus-prime-b550m...  123.75        151,68€
# 4  https://www.pccomponentes.com/placa-base-asus-...  174.95            NaN
#
#    rating  opiniones categoria
# 0     4.6        598      ASUS
# 1     4.5        953      ASUS
# ...

# %%
df1['precio_tachado'] = df1['precio_tachado'].str.replace(',', '.', regex=False)
df1['precio_tachado'] = df1['precio_tachado'].str.replace(r'€', '', regex=True)
# df1['precio_tachado'] = df1['precio_tachado'].fillna(df1['precio'])
df1['precio_tachado'] = df1['precio_tachado'].astype(float)
df1.head()
# Out:
#    producto_id            timestamp                       nombre  \
# 0            1  2025-02-21 17:23:39         ASUS PRIME B760-PLUS
# 1            2  2025-02-21 17:23:39    ASUS TUF GAMING B650-PLUS
# 2            3  2025-02-21 17:23:39    ASUS PRIME B650-PLUS WIFI
# 3            4  2025-02-21 17:23:39   ASUS PRIME B550M-A WIFI II
# 4            5  2025-02-21 17:23:39  ASUS TUF GAMING B650-E WIFI
#
#                                                  url  precio  precio_tachado  \
# 0  https://www.pccomponentes.com/asus-prime-b760-...  134.00          164.90
# 1  https://www.pccomponentes.com/asus-tuf-gaming-...  213.15          267.51
# 2  https://www.pccomponentes.com/placa-base-asus-...  164.95             NaN
# 3  https://www.pccomponentes.com/asus-prime-b550m...  123.75          151.68
# 4  https://www.pccomponentes.com/placa-base-asus-...  174.95             NaN
#
#    rating  opiniones categoria
# 0     4.6        598      ASUS
# 1     4.5        953      ASUS
# ...

# %%
df1['timestamp'] = pd.to_datetime(df1['timestamp'])
df1.head()
# Out:
#    producto_id           timestamp                       nombre  \
# 0            1 2025-02-21 17:23:39         ASUS PRIME B760-PLUS
# 1            2 2025-02-21 17:23:39    ASUS TUF GAMING B650-PLUS
# 2            3 2025-02-21 17:23:39    ASUS PRIME B650-PLUS WIFI
# 3            4 2025-02-21 17:23:39   ASUS PRIME B550M-A WIFI II
# 4            5 2025-02-21 17:23:39  ASUS TUF GAMING B650-E WIFI
#
#                                                  url  precio  precio_tachado  \
# 0  https://www.pccomponentes.com/asus-prime-b760-...  134.00          164.90
# 1  https://www.pccomponentes.com/asus-tuf-gaming-...  213.15          267.51
# 2  https://www.pccomponentes.com/placa-base-asus-...  164.95             NaN
# 3  https://www.pccomponentes.com/asus-prime-b550m...  123.75          151.68
# 4  https://www.pccomponentes.com/placa-base-asus-...  174.95             NaN
#
#    rating  opiniones categoria
# 0     4.6        598      ASUS
# 1     4.5        953      ASUS
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 454 entries, 0 to 453
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   producto_id     454 non-null    int64
#  1   timestamp       454 non-null    datetime64[ns]
#  2   nombre          454 non-null    object
#  3   url             454 non-null    object
#  4   precio          454 non-null    float64
#  5   precio_tachado  169 non-null    float64
#  6   rating          402 non-null    float64
#  7   opiniones       454 non-null    int32
#  8   categoria       454 non-null    object
# dtypes: datetime64[ns](1), float64(3), int32(1), int64(1), object(3)
# memory usage: 30.3+ KB

# %%
df1.to_csv('productos_componentes_pc_limpio.csv', index=False)

# %%
df2 = pd.read_csv('../data/caracteristicas_productos_componentes_pc.csv')
df2.head()
# Out:
#                                             Producto  \
# 0  NZXT Kraken Elite 360 RGB Kit de Refrigeración...
# 1  Forgeon Bolt PSU 1000W 80+ Gold Full Modular N...
# 2           SanDisk Extreme SSD Externo V2 4TB USB-C
# 3  Tempest Liquid Cooler 240 ARGB Kit Refrigeraci...
# 4  Forgeon Overmind Ventiladores Suplementarios I...
#
#                                     Característica_1  \
# 0  PERSONALIZACIÓN QUE DESTACA: Exhibe tu imagen ...
# 1                                     Ahorra espacio
# 2  Potente y portátil. Obtén el veloz rendimiento...
# 3  Enfría tu procesador: Olvida los viejos ventil...
# 4  Iluminación Atractiva: Los ventiladores Forgeo...
#
#                                     Característica_2  \
# 0  PANTALLA LCD CON GRAN ÁNGULO DE VISIÓN: Pantal...
# 1                                  Fácil instalación
# 2  Lo suficientemente resistente como para llevar...
# 3  Disfruta de su instalación: Referente a su ins...
# ...

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 17 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Producto           10 non-null     object
#  1   Característica_1   10 non-null     object
#  2   Característica_2   10 non-null     object
#  3   Característica_3   10 non-null     object
#  4   Característica_4   10 non-null     object
#  5   Característica_5   10 non-null     object
#  6   Característica_6   10 non-null     object
#  7   Característica_7   10 non-null     object
#  8   Característica_8   10 non-null     object
#  9   Característica_9   10 non-null     object
#  10  Característica_10  10 non-null     object
#  11  Característica_11  10 non-null     object
#  12  Característica_12  10 non-null     object
#  13  Característica_13  10 non-null     object
#  14  Característica_14  10 non-null     object
#  15  Característica_15  10 non-null     object
# ...

# %%
column_names = {
    "Característica_1": "detalle_unico",
    "Característica_2": "pantalla",
    "Característica_3": "bomba",
    "Característica_4": "refrigeracion",
    "Característica_5": "instalacion",
    "Característica_6": "tubos_reforzados",
    "Característica_7": "compatibilidad_procesador",
    }

df2.rename(columns=column_names, inplace=True)
   
df2.head()
# Out:
#                                             Producto  \
# 0  NZXT Kraken Elite 360 RGB Kit de Refrigeración...
# 1  Forgeon Bolt PSU 1000W 80+ Gold Full Modular N...
# 2           SanDisk Extreme SSD Externo V2 4TB USB-C
# 3  Tempest Liquid Cooler 240 ARGB Kit Refrigeraci...
# 4  Forgeon Overmind Ventiladores Suplementarios I...
#
#                                        detalle_unico  \
# 0  PERSONALIZACIÓN QUE DESTACA: Exhibe tu imagen ...
# 1                                     Ahorra espacio
# 2  Potente y portátil. Obtén el veloz rendimiento...
# 3  Enfría tu procesador: Olvida los viejos ventil...
# 4  Iluminación Atractiva: Los ventiladores Forgeo...
#
#                                             pantalla  \
# 0  PANTALLA LCD CON GRAN ÁNGULO DE VISIÓN: Pantal...
# 1                                  Fácil instalación
# 2  Lo suficientemente resistente como para llevar...
# 3  Disfruta de su instalación: Referente a su ins...
# ...

# %%
df2['detalle_unico'] = df2['detalle_unico'].str.replace(r'PERSONALIZACIÓN QUE DESTACA:', '', regex=True)
df2['pantalla'] = df2['pantalla'].str.replace(r'PANTALLA LCD CON GRAN ÁNGULO DE VISIÓN:', '', regex=True)
df2['bomba'] = df2['bomba'].str.replace(r'\BOMBA DE ALTO RENDIMIENTO:', '', regex=True)
df2['refrigeracion'] = df2['refrigeracion'].str.replace(r'REFRIGERACIÓN COLORIDA:', '', regex=True)
df2['instalacion'] = df2['instalacion'].str.replace(r'FÁCIL DE INSTALAR:', '', regex=True)
df2['tubos_reforzados'] = df2['tubos_reforzados'].str.replace(r'TUBOS REFORZADOS:', '', regex=True)
df2['compatibilidad_procesador'] = df2['compatibilidad_procesador'].str.replace(r'COMPATIBILIDAD DE PROCESADOR:', '', regex=True)

df2.head()
# Out:
#                                             Producto  \
# 0  NZXT Kraken Elite 360 RGB Kit de Refrigeración...
# 1  Forgeon Bolt PSU 1000W 80+ Gold Full Modular N...
# 2           SanDisk Extreme SSD Externo V2 4TB USB-C
# 3  Tempest Liquid Cooler 240 ARGB Kit Refrigeraci...
# 4  Forgeon Overmind Ventiladores Suplementarios I...
#
#                                        detalle_unico  \
# 0   Exhibe tu imagen estática o GIF animado prefe...
# 1                                     Ahorra espacio
# 2  Potente y portátil. Obtén el veloz rendimiento...
# 3  Enfría tu procesador: Olvida los viejos ventil...
# 4  Iluminación Atractiva: Los ventiladores Forgeo...
#
#                                             pantalla  \
# 0   Pantalla LCD de 2,36” de diámetro con gran án...
# 1                                  Fácil instalación
# 2  Lo suficientemente resistente como para llevar...
# 3  Disfruta de su instalación: Referente a su ins...
# ...

# %%
df2 = df2.drop(['Característica_8','Característica_9','Característica_10', 
               'Característica_11','Característica_12','Característica_13',
               'Característica_14','Característica_15','Característica_16'], axis=1)

df2.head()
# Out:
#                                             Producto  \
# 0  NZXT Kraken Elite 360 RGB Kit de Refrigeración...
# 1  Forgeon Bolt PSU 1000W 80+ Gold Full Modular N...
# 2           SanDisk Extreme SSD Externo V2 4TB USB-C
# 3  Tempest Liquid Cooler 240 ARGB Kit Refrigeraci...
# 4  Forgeon Overmind Ventiladores Suplementarios I...
#
#                                        detalle_unico  \
# 0   Exhibe tu imagen estática o GIF animado prefe...
# 1                                     Ahorra espacio
# 2  Potente y portátil. Obtén el veloz rendimiento...
# 3  Enfría tu procesador: Olvida los viejos ventil...
# 4  Iluminación Atractiva: Los ventiladores Forgeo...
#
#                                             pantalla  \
# 0   Pantalla LCD de 2,36” de diámetro con gran án...
# 1                                  Fácil instalación
# 2  Lo suficientemente resistente como para llevar...
# 3  Disfruta de su instalación: Referente a su ins...
# ...

# %%
df2["Producto"][0]
# Out:
# 'NZXT Kraken Elite 360 RGB Kit de Refrigeración Líquida'

# %%
import os

file_path = "../data/productosPortatil-limpio.csv"

if os.path.exists(file_path):
    print(f"✅ El archivo {file_path} EXISTE.")
else:
    print(f"❌ ERROR: No se encontró el archivo {file_path}. Verifica la ruta.")
# Out:
# ✅ El archivo ../data/productosPortatil-limpio.csv EXISTE.

# %%
import pandas as pd

file_path = "../data/productosPortatil-limpio.csv"

try:
    df = pd.read_csv(file_path)
    print(df.info())  # Ver detalles del DataFrame
    print(df.head())  # Ver primeras filas
except Exception as e:
    print(f"❌ ERROR al cargar el archivo: {e}")
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 494 entries, 0 to 493
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   producto_id     494 non-null    int64
#  1   timestamp       494 non-null    object
#  2   nombre          494 non-null    object
#  3   url             494 non-null    object
#  4   precio          494 non-null    float64
#  5   precio_tachado  272 non-null    float64
#  6   rating          382 non-null    float64
#  7   opiniones       494 non-null    int64
#  8   categoria       494 non-null    object
# dtypes: float64(3), int64(2), object(4)
# memory usage: 34.9+ KB
# None
#    producto_id            timestamp  \
# 0            1  2025-02-21 17:19:06
# 1            2  2025-02-21 17:19:06
# 2            3  2025-02-21 17:19:06
# 3            4  2025-02-21 17:19:06
# 4            5  2025-02-21 17:19:06
#
#                                               nombre  \
# ...
