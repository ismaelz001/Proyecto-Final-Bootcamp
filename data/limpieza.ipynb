# %%
import pandas as pd

# %%
df = pd.read_csv('productosPortatil.csv')
df.head(10)
# Out:
#    producto_id            timestamp  \
# 0            1  2025-02-26 06:34:12
# 1            2  2025-02-26 06:34:12
# 2            3  2025-02-26 06:34:12
# 3            4  2025-02-26 06:34:12
# 4            5  2025-02-26 06:34:12
# 5            6  2025-02-26 06:34:12
# 6            7  2025-02-26 06:34:12
# 7            8  2025-02-26 06:34:12
# 8            9  2025-02-26 06:34:12
# 9           10  2025-02-26 06:34:12
#
#                                               nombre  \
# 0  MSI Modern 15 F13MG-246XES Intel Core i7-1355U...
# 1  Lenovo IdeaPad 1 Gen 7 15ALC7 AMD Ryzen 7 5700...
# 2  Lenovo IdeaPad 1 15ALC7 AMD Ryzen 7 5700U/16GB...
# 3  HP 15-fd0020ns Intel Core i7-1355U/16GB/1TB SS...
# 4  MSI Modern 15 B7M-243XES AMD Ryzen 7 7730U/16G...
# 5  MSI Modern 14 F13MG-203XES Intel Core i7-1355U...
# 6  MSI Modern 15 F13MG-248XES Intel Core i5-1334U...
# 7  MSI Modern 15 B7M-041XES AMD Ryzen 5 7530U/16G...
# 8  ASUS Vivobook F1504VA-NJ2237 Intel Core i5-133...
# 9  ASUS Vivobook 15 M1502YA-NJ448 AMD Ryzen 7 773...
#
#                                                  url precio precio_tachado  \
# 0  https://www.pccomponentes.com/portatil-msi-mod...   799€        898,99€
# 1  https://www.pccomponentes.com/portatil-lenovo-...   479€           699€
# 2  https://www.pccomponentes.com/portatil-lenovo-...   489€           579€
# 3  https://www.pccomponentes.com/hp-15-fd0020ns-i...   659€           799€
# 4  https://www.pccomponentes.com/msi-modern-15-b7...   619€           899€
# 5  https://www.pccomponentes.com/portatil-msi-mod...   749€        808,99€
# 6  https://www.pccomponentes.com/portatil-msi-mod...   599€           889€
# 7  https://www.pccomponentes.com/msi-modern-15-b7...   579€           649€
# 8  https://www.pccomponentes.com/portatil-asus-vi...   489€           599€
# 9  https://www.pccomponentes.com/portatil-asus-vi...   529€           579€
#
#   rating       opiniones                            categoria
# 0  4,5/5   492 opiniones  Portátiles para estudiar o trabajar
# 1  4,5/5   598 opiniones  Portátiles para estudiar o trabajar
# 2  4,5/5   590 opiniones  Portátiles para estudiar o trabajar
# 3  4,6/5  1117 opiniones  Portátiles para estudiar o trabajar
# 4  4,5/5   752 opiniones  Portátiles para estudiar o trabajar
# 5  4,6/5   135 opiniones  Portátiles para estudiar o trabajar
# 6  4,5/5   593 opiniones  Portátiles para estudiar o trabajar
# 7  4,5/5   915 opiniones  Portátiles para estudiar o trabajar
# 8    NaN             NaN  Portátiles para estudiar o trabajar
# 9  4,5/5   968 opiniones  Portátiles para estudiar o trabajar

# %%
df.describe()
# Out:
#        producto_id
# count   275.000000
# mean    138.000000
# std      79.529869
# min       1.000000
# 25%      69.500000
# 50%     138.000000
# 75%     206.500000
# max     275.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 275 entries, 0 to 274
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   producto_id     275 non-null    int64
#  1   timestamp       275 non-null    object
#  2   nombre          275 non-null    object
#  3   url             275 non-null    object
#  4   precio          275 non-null    object
#  5   precio_tachado  158 non-null    object
#  6   rating          232 non-null    object
#  7   opiniones       232 non-null    object
#  8   categoria       275 non-null    object
# dtypes: int64(1), object(8)
# memory usage: 19.5+ KB

# %%
df["nombre"] = df["nombre"].astype(str)
df["url"] = df["url"].astype(str)
df["categoria"] = df["categoria"].astype(str)

# %%
df['opiniones'] = df['opiniones'].str.replace(r'\D', '', regex=True)
df['opiniones'] = df['opiniones'].fillna(0)
df['opiniones'] = df['opiniones'].astype(int)
df.head()
# Out:
#    producto_id            timestamp  \
# 0            1  2025-02-26 06:34:12
# 1            2  2025-02-26 06:34:12
# 2            3  2025-02-26 06:34:12
# 3            4  2025-02-26 06:34:12
# 4            5  2025-02-26 06:34:12
#
#                                               nombre  \
# 0  MSI Modern 15 F13MG-246XES Intel Core i7-1355U...
# 1  Lenovo IdeaPad 1 Gen 7 15ALC7 AMD Ryzen 7 5700...
# 2  Lenovo IdeaPad 1 15ALC7 AMD Ryzen 7 5700U/16GB...
# 3  HP 15-fd0020ns Intel Core i7-1355U/16GB/1TB SS...
# 4  MSI Modern 15 B7M-243XES AMD Ryzen 7 7730U/16G...
#
#                                                  url precio precio_tachado  \
# 0  https://www.pccomponentes.com/portatil-msi-mod...   799€        898,99€
# 1  https://www.pccomponentes.com/portatil-lenovo-...   479€           699€
# 2  https://www.pccomponentes.com/portatil-lenovo-...   489€           579€
# 3  https://www.pccomponentes.com/hp-15-fd0020ns-i...   659€           799€
# 4  https://www.pccomponentes.com/msi-modern-15-b7...   619€           899€
#
#   rating  opiniones                            categoria
# 0  4,5/5        492  Portátiles para estudiar o trabajar
# 1  4,5/5        598  Portátiles para estudiar o trabajar
# 2  4,5/5        590  Portátiles para estudiar o trabajar
# 3  4,6/5       1117  Portátiles para estudiar o trabajar
# 4  4,5/5        752  Portátiles para estudiar o trabajar

# %%
df['rating'] = df['rating'].str.replace(',', '.', regex=False)
df['rating'] = df['rating'].str.replace(r'/5', '', regex=True)
df['rating'] = df['rating'].astype(float)

# %%
df['precio'] = df['precio'].str.replace('.', '', regex=False)
df['precio'] = df['precio'].str.replace(',', '.', regex=False)
df['precio'] = df['precio'].str.replace(r'€', '', regex=True)
df['precio'] = df['precio'].astype(float)

# %%
df.head()
# Out:
#    producto_id            timestamp  \
# 0            1  2025-02-26 06:34:12
# 1            2  2025-02-26 06:34:12
# 2            3  2025-02-26 06:34:12
# 3            4  2025-02-26 06:34:12
# 4            5  2025-02-26 06:34:12
#
#                                               nombre  \
# 0  MSI Modern 15 F13MG-246XES Intel Core i7-1355U...
# 1  Lenovo IdeaPad 1 Gen 7 15ALC7 AMD Ryzen 7 5700...
# 2  Lenovo IdeaPad 1 15ALC7 AMD Ryzen 7 5700U/16GB...
# 3  HP 15-fd0020ns Intel Core i7-1355U/16GB/1TB SS...
# 4  MSI Modern 15 B7M-243XES AMD Ryzen 7 7730U/16G...
#
#                                                  url  precio precio_tachado  \
# 0  https://www.pccomponentes.com/portatil-msi-mod...   799.0        898,99€
# 1  https://www.pccomponentes.com/portatil-lenovo-...   479.0           699€
# 2  https://www.pccomponentes.com/portatil-lenovo-...   489.0           579€
# 3  https://www.pccomponentes.com/hp-15-fd0020ns-i...   659.0           799€
# 4  https://www.pccomponentes.com/msi-modern-15-b7...   619.0           899€
#
#    rating  opiniones                            categoria
# 0     4.5        492  Portátiles para estudiar o trabajar
# 1     4.5        598  Portátiles para estudiar o trabajar
# 2     4.5        590  Portátiles para estudiar o trabajar
# 3     4.6       1117  Portátiles para estudiar o trabajar
# 4     4.5        752  Portátiles para estudiar o trabajar

# %%
df['precio_tachado'] = df['precio_tachado'].str.replace('.', '', regex=False)
df['precio_tachado'] = df['precio_tachado'].str.replace(',', '.', regex=False)
df['precio_tachado'] = df['precio_tachado'].str.replace(r'€', '', regex=True)
# df['precio_tachado'] = df['precio_tachado'].fillna(df['precio'])
df['precio_tachado'] = df['precio_tachado'].astype(float)
df.head()
# Out:
#    producto_id            timestamp  \
# 0            1  2025-02-26 06:34:12
# 1            2  2025-02-26 06:34:12
# 2            3  2025-02-26 06:34:12
# 3            4  2025-02-26 06:34:12
# 4            5  2025-02-26 06:34:12
#
#                                               nombre  \
# 0  MSI Modern 15 F13MG-246XES Intel Core i7-1355U...
# 1  Lenovo IdeaPad 1 Gen 7 15ALC7 AMD Ryzen 7 5700...
# 2  Lenovo IdeaPad 1 15ALC7 AMD Ryzen 7 5700U/16GB...
# 3  HP 15-fd0020ns Intel Core i7-1355U/16GB/1TB SS...
# 4  MSI Modern 15 B7M-243XES AMD Ryzen 7 7730U/16G...
#
#                                                  url  precio  precio_tachado  \
# 0  https://www.pccomponentes.com/portatil-msi-mod...   799.0          898.99
# 1  https://www.pccomponentes.com/portatil-lenovo-...   479.0          699.00
# 2  https://www.pccomponentes.com/portatil-lenovo-...   489.0          579.00
# 3  https://www.pccomponentes.com/hp-15-fd0020ns-i...   659.0          799.00
# 4  https://www.pccomponentes.com/msi-modern-15-b7...   619.0          899.00
#
#    rating  opiniones                            categoria
# 0     4.5        492  Portátiles para estudiar o trabajar
# 1     4.5        598  Portátiles para estudiar o trabajar
# 2     4.5        590  Portátiles para estudiar o trabajar
# 3     4.6       1117  Portátiles para estudiar o trabajar
# 4     4.5        752  Portátiles para estudiar o trabajar

# %%
df['timestamp'] = pd.to_datetime(df['timestamp'])

# %%
df.head(5)
# Out:
#    producto_id           timestamp  \
# 0            1 2025-02-26 06:34:12
# 1            2 2025-02-26 06:34:12
# 2            3 2025-02-26 06:34:12
# 3            4 2025-02-26 06:34:12
# 4            5 2025-02-26 06:34:12
#
#                                               nombre  \
# 0  MSI Modern 15 F13MG-246XES Intel Core i7-1355U...
# 1  Lenovo IdeaPad 1 Gen 7 15ALC7 AMD Ryzen 7 5700...
# 2  Lenovo IdeaPad 1 15ALC7 AMD Ryzen 7 5700U/16GB...
# 3  HP 15-fd0020ns Intel Core i7-1355U/16GB/1TB SS...
# 4  MSI Modern 15 B7M-243XES AMD Ryzen 7 7730U/16G...
#
#                                                  url  precio  precio_tachado  \
# 0  https://www.pccomponentes.com/portatil-msi-mod...   799.0          898.99
# 1  https://www.pccomponentes.com/portatil-lenovo-...   479.0          699.00
# 2  https://www.pccomponentes.com/portatil-lenovo-...   489.0          579.00
# 3  https://www.pccomponentes.com/hp-15-fd0020ns-i...   659.0          799.00
# 4  https://www.pccomponentes.com/msi-modern-15-b7...   619.0          899.00
#
#    rating  opiniones                            categoria
# 0     4.5        492  Portátiles para estudiar o trabajar
# 1     4.5        598  Portátiles para estudiar o trabajar
# 2     4.5        590  Portátiles para estudiar o trabajar
# 3     4.6       1117  Portátiles para estudiar o trabajar
# 4     4.5        752  Portátiles para estudiar o trabajar

# %%
df.to_csv('productosPortatil-limpio.csv', index=False)

# %%
# 📌 Verificar que la columna de precio existe
if "precio" not in df.columns:
    print("❌ Error: La columna 'precio' no existe en el dataset.")
else:
    # 🔍 Revisar estadísticas generales de los precios
    print("📊 Estadísticas generales de precios:")
    print(df["precio"].describe())

    # 📌 Filtrar precios extremadamente bajos (Ejemplo: < 50€) o precios inusualmente altos (> 10,000€)
    precios_erroneos = df[(df["precio"] < 50) | (df["precio"] > 10000)]

    # 📌 Mostrar los datos erróneos
    if not precios_erroneos.empty:
        print("\n⚠️ Posibles errores detectados en los precios:")
        display(precios_erroneos)
    else:
        print("\n✅ No se encontraron precios sospechosos.")
# Out:
# 📊 Estadísticas generales de precios:
# count     275.000000
# mean     1131.666255
# std       735.783075
# min       189.990000
# 25%       518.720000
# 50%       949.000000
# 75%      1617.450000
# max      5198.990000
# Name: precio, dtype: float64
#
# ✅ No se encontraron precios sospechosos.

# %%
print(df[df["producto_id"]== 105])
# Out:
#      producto_id           timestamp  \
# 104          105 2025-02-26 06:34:59
#
#                                                 nombre  \
# 104  ASUS ProArt P16 OLED H7606WI-ME034W AMD Ryzen ...
#
#                                                    url  precio  \
# 104  https://www.pccomponentes.com/portatil-asus-pr...  2599.0
#
#      precio_tachado  rating  opiniones  \
# 104             NaN     3.9          4
#
#                                      categoria
# 104  Portátiles para edición de vídeo y diseño

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 275 entries, 0 to 274
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   producto_id     275 non-null    int64
#  1   timestamp       275 non-null    datetime64[ns]
#  2   nombre          275 non-null    object
#  3   url             275 non-null    object
#  4   precio          275 non-null    float64
#  5   precio_tachado  158 non-null    float64
#  6   rating          232 non-null    float64
#  7   opiniones       275 non-null    int32
#  8   categoria       275 non-null    object
# dtypes: datetime64[ns](1), float64(3), int32(1), int64(1), object(3)
# memory usage: 18.4+ KB
