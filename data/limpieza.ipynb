# %%
import pandas as pd

# %%
df = pd.read_csv('productosPortatil.csv')
df.head(10)
# Out:
#    producto_id            timestamp  \
# 0            1  2025-02-18 12:31:30
# 1            2  2025-02-18 12:31:30
# 2            3  2025-02-18 12:31:30
# 3            4  2025-02-18 12:31:30
# 4            5  2025-02-18 12:31:30
# 5            6  2025-02-18 12:31:30
# 6            7  2025-02-18 12:31:30
# 7            8  2025-02-18 12:31:30
# 8            9  2025-02-18 12:31:30
# 9           10  2025-02-18 12:31:30
#
#                                               nombre  \
# 0  PcCom Ready AMD Ryzen 7 5800X / 32GB / 1TB SSD...
# 1  PcCom Ready AMD Ryzen 7 5800X / 32GB / 1TB SSD...
# 2    PcCom Work Intel Core i5-12400 / 32GB / 1TB SSD
# 3  PcCom Ready AMD Ryzen 7 5800X / 32GB / 2TB SSD...
# 4  PcCom Ultimate Ryzen 7 9800X3D / 64GB / 2TB M....
# 5  PcCom Work Intel Core i5-12400 / 32GB / 1TB SS...
# 6  PcCom Ready AMD Ryzen 7 5800X / 32GB / 1TB SSD...
# 7  PcCom Ready AMD Ryzen 7 5800X / 32GB / 1TB SSD...
# 8  PcCom Ready AMD Ryzen 7 5800X / 32GB / 2TB SSD...
# 9  PcCom Imperial AMD Ryzen 7 7800X3D / 32GB / 2T...
#
#                                                  url  precio precio_tachado  \
# 0  https://www.pccomponentes.com/pccom-ready-amd-...  1.339€      1.760,25€
# 1  https://www.pccomponentes.com/pccom-ready-amd-...  1.229€      1.449,42€
# 2  https://www.pccomponentes.com/ordenador-sobrem...    509€        593,05€
# 3  https://www.pccomponentes.com/ordenador-sobrem...  1.429€      1.662,47€
# 4  https://www.pccomponentes.com/ordenador-sobrem...  3.799€      4.270,09€
# 5  https://www.pccomponentes.com/ordenador-sobrem...    649€        743,05€
# 6  https://www.pccomponentes.com/pccom-ready-amd-...  1.329€      1.549,42€
# 7  https://www.pccomponentes.com/pccom-ready-amd-...  1.209€      1.432,33€
# 8  https://www.pccomponentes.com/ordenador-sobrem...  1.299€      1.522,47€
# 9  https://www.pccomponentes.com/ordenador-sobrem...  2.399€      2.867,52€
#
#   rating      opiniones     categoria
# 0  4,7/5  902 opiniones  PC sobremesa
# 1  4,7/5  902 opiniones  PC sobremesa
# 2  4,5/5  608 opiniones  PC sobremesa
# 3  4,7/5  902 opiniones  PC sobremesa
# 4  3,6/5    7 opiniones  PC sobremesa
# 5  4,5/5  608 opiniones  PC sobremesa
# 6  4,7/5  217 opiniones  PC sobremesa
# 7  4,7/5  217 opiniones  PC sobremesa
# 8  4,7/5  902 opiniones  PC sobremesa
# 9  4,6/5  410 opiniones  PC sobremesa

# %%
df.describe()
# Out:
#        producto_id
# count   124.000000
# mean     62.500000
# std      35.939764
# min       1.000000
# 25%      31.750000
# 50%      62.500000
# 75%      93.250000
# max     124.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 124 entries, 0 to 123
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   producto_id     124 non-null    int64
#  1   timestamp       124 non-null    object
#  2   nombre          124 non-null    object
#  3   url             124 non-null    object
#  4   precio          124 non-null    object
#  5   precio_tachado  103 non-null    object
#  6   rating          121 non-null    object
#  7   opiniones       121 non-null    object
#  8   categoria       124 non-null    object
# dtypes: int64(1), object(8)
# memory usage: 8.8+ KB

# %%
df["nombre"] = df["nombre"].astype(str)
df["url"] = df["url"].astype(str)
df["categoria"] = df["categoria"].astype(str)

# %%
df['opiniones'] = df['opiniones'].str.replace(r'\D', '', regex=True)
df['opiniones'] = df['opiniones'].fillna(0)
df['opiniones'] = df['opiniones'].astype(int)
df.head()
# Out:
#    producto_id            timestamp  \
# 0            1  2025-02-18 12:31:30
# 1            2  2025-02-18 12:31:30
# 2            3  2025-02-18 12:31:30
# 3            4  2025-02-18 12:31:30
# 4            5  2025-02-18 12:31:30
#
#                                               nombre  \
# 0  PcCom Ready AMD Ryzen 7 5800X / 32GB / 1TB SSD...
# 1  PcCom Ready AMD Ryzen 7 5800X / 32GB / 1TB SSD...
# 2    PcCom Work Intel Core i5-12400 / 32GB / 1TB SSD
# 3  PcCom Ready AMD Ryzen 7 5800X / 32GB / 2TB SSD...
# 4  PcCom Ultimate Ryzen 7 9800X3D / 64GB / 2TB M....
#
#                                                  url  precio precio_tachado  \
# 0  https://www.pccomponentes.com/pccom-ready-amd-...  1.339€      1.760,25€
# 1  https://www.pccomponentes.com/pccom-ready-amd-...  1.229€      1.449,42€
# 2  https://www.pccomponentes.com/ordenador-sobrem...    509€        593,05€
# 3  https://www.pccomponentes.com/ordenador-sobrem...  1.429€      1.662,47€
# 4  https://www.pccomponentes.com/ordenador-sobrem...  3.799€      4.270,09€
#
#   rating  opiniones     categoria
# 0  4,7/5        902  PC sobremesa
# 1  4,7/5        902  PC sobremesa
# 2  4,5/5        608  PC sobremesa
# 3  4,7/5        902  PC sobremesa
# 4  3,6/5          7  PC sobremesa

# %%
df['rating'] = df['rating'].str.replace(',', '.', regex=False)
df['rating'] = df['rating'].str.replace(r'/5', '', regex=True)
df['rating'] = df['rating'].astype(float)

# %%
df['precio'] = df['precio'].str.replace('.', '', regex=False)
df['precio'] = df['precio'].str.replace(',', '.', regex=False)
df['precio'] = df['precio'].str.replace(r'€', '', regex=True)
df['precio'] = df['precio'].astype(float)

# %%
df.head()
# Out:
#    producto_id            timestamp  \
# 0            1  2025-02-18 12:31:30
# 1            2  2025-02-18 12:31:30
# 2            3  2025-02-18 12:31:30
# 3            4  2025-02-18 12:31:30
# 4            5  2025-02-18 12:31:30
#
#                                               nombre  \
# 0  PcCom Ready AMD Ryzen 7 5800X / 32GB / 1TB SSD...
# 1  PcCom Ready AMD Ryzen 7 5800X / 32GB / 1TB SSD...
# 2    PcCom Work Intel Core i5-12400 / 32GB / 1TB SSD
# 3  PcCom Ready AMD Ryzen 7 5800X / 32GB / 2TB SSD...
# 4  PcCom Ultimate Ryzen 7 9800X3D / 64GB / 2TB M....
#
#                                                  url  precio precio_tachado  \
# 0  https://www.pccomponentes.com/pccom-ready-amd-...  1339.0      1.760,25€
# 1  https://www.pccomponentes.com/pccom-ready-amd-...  1229.0      1.449,42€
# 2  https://www.pccomponentes.com/ordenador-sobrem...   509.0        593,05€
# 3  https://www.pccomponentes.com/ordenador-sobrem...  1429.0      1.662,47€
# 4  https://www.pccomponentes.com/ordenador-sobrem...  3799.0      4.270,09€
#
#    rating  opiniones     categoria
# 0     4.7        902  PC sobremesa
# 1     4.7        902  PC sobremesa
# 2     4.5        608  PC sobremesa
# 3     4.7        902  PC sobremesa
# 4     3.6          7  PC sobremesa

# %%
df['precio_tachado'] = df['precio_tachado'].str.replace('.', '', regex=False)
df['precio_tachado'] = df['precio_tachado'].str.replace(',', '.', regex=False)
df['precio_tachado'] = df['precio_tachado'].str.replace(r'€', '', regex=True)
# df['precio_tachado'] = df['precio_tachado'].fillna(df['precio'])
df['precio_tachado'] = df['precio_tachado'].astype(float)
df.head()
# Out:
#    producto_id            timestamp  \
# 0            1  2025-02-18 12:31:30
# 1            2  2025-02-18 12:31:30
# 2            3  2025-02-18 12:31:30
# 3            4  2025-02-18 12:31:30
# 4            5  2025-02-18 12:31:30
#
#                                               nombre  \
# 0  PcCom Ready AMD Ryzen 7 5800X / 32GB / 1TB SSD...
# 1  PcCom Ready AMD Ryzen 7 5800X / 32GB / 1TB SSD...
# 2    PcCom Work Intel Core i5-12400 / 32GB / 1TB SSD
# 3  PcCom Ready AMD Ryzen 7 5800X / 32GB / 2TB SSD...
# 4  PcCom Ultimate Ryzen 7 9800X3D / 64GB / 2TB M....
#
#                                                  url  precio  precio_tachado  \
# 0  https://www.pccomponentes.com/pccom-ready-amd-...  1339.0         1760.25
# 1  https://www.pccomponentes.com/pccom-ready-amd-...  1229.0         1449.42
# 2  https://www.pccomponentes.com/ordenador-sobrem...   509.0          593.05
# 3  https://www.pccomponentes.com/ordenador-sobrem...  1429.0         1662.47
# 4  https://www.pccomponentes.com/ordenador-sobrem...  3799.0         4270.09
#
#    rating  opiniones     categoria
# 0     4.7        902  PC sobremesa
# 1     4.7        902  PC sobremesa
# 2     4.5        608  PC sobremesa
# 3     4.7        902  PC sobremesa
# 4     3.6          7  PC sobremesa

# %%
df['timestamp'] = pd.to_datetime(df['timestamp'])

# %%
df.head()
# Out:
#    producto_id           timestamp  \
# 0            1 2025-02-18 12:31:30
# 1            2 2025-02-18 12:31:30
# 2            3 2025-02-18 12:31:30
# 3            4 2025-02-18 12:31:30
# 4            5 2025-02-18 12:31:30
#
#                                               nombre  \
# 0  PcCom Ready AMD Ryzen 7 5800X / 32GB / 1TB SSD...
# 1  PcCom Ready AMD Ryzen 7 5800X / 32GB / 1TB SSD...
# 2    PcCom Work Intel Core i5-12400 / 32GB / 1TB SSD
# 3  PcCom Ready AMD Ryzen 7 5800X / 32GB / 2TB SSD...
# 4  PcCom Ultimate Ryzen 7 9800X3D / 64GB / 2TB M....
#
#                                                  url  precio  precio_tachado  \
# 0  https://www.pccomponentes.com/pccom-ready-amd-...  1339.0         1760.25
# 1  https://www.pccomponentes.com/pccom-ready-amd-...  1229.0         1449.42
# 2  https://www.pccomponentes.com/ordenador-sobrem...   509.0          593.05
# 3  https://www.pccomponentes.com/ordenador-sobrem...  1429.0         1662.47
# 4  https://www.pccomponentes.com/ordenador-sobrem...  3799.0         4270.09
#
#    rating  opiniones     categoria
# 0     4.7        902  PC sobremesa
# 1     4.7        902  PC sobremesa
# 2     4.5        608  PC sobremesa
# 3     4.7        902  PC sobremesa
# 4     3.6          7  PC sobremesa

# %%
df.to_csv('productosPortatil-limpio.csv', index=False)

# %%
df1 = pd.read_csv('productos_componentes_pc.csv')
df1.head(10)
# Out:
#    producto_id            timestamp  \
# 0            1  2025-02-18 12:32:30
# 1            2  2025-02-18 12:32:30
# 2            3  2025-02-18 12:32:30
# 3            4  2025-02-18 12:32:30
# 4            5  2025-02-18 12:32:30
# 5            6  2025-02-18 12:32:30
# 6            7  2025-02-18 12:32:30
# 7            8  2025-02-18 12:32:30
# 8            9  2025-02-18 12:32:30
# 9           10  2025-02-18 12:32:30
#
#                                               nombre  \
# 0  Tempest Liquid Cooler 360 ARGB Kit de Refriger...
# 1  Tempest Liquid Cooler 360 Kit de Refrigeración...
# 2  Forgeon Azoth 240 ARGB Kit de Refrigeración Lí...
# 3  Nfortec ATRIA X Kit de Refrigeración Líquida 3...
# 4  Corsair NAUTILUS 360 RS ARGB Kit Refrigeración...
# 5  Cooler Master MasterLiquid 240L Core ARGB Kit ...
# 6  Corsair iCUE H150i ELITE LCD XT Kit de Refrige...
# 7  Tempest Liquid Cooler 240 Kit Refrigeración Lí...
# 8  Tempest Liquid Cooler 240 RGB Kit de Refrigera...
# 9  Tempest Liquid Cooler 120 RGB Kit de Refrigera...
#
#                                                  url   precio precio_tachado  \
# 0  https://www.pccomponentes.com/tempest-liquid-c...   76,99€         87,99€
# 1  https://www.pccomponentes.com/tempest-liquid-c...   68,99€         78,98€
# 2  https://www.pccomponentes.com/forgeon-azoth-24...   75,99€        149,99€
# 3  https://www.pccomponentes.com/nfortec-atria-x-...   94,99€            NaN
# 4  https://www.pccomponentes.com/corsair-nautilus...  128,99€            NaN
# 5  https://www.pccomponentes.com/cooler-master-ma...   79,99€            NaN
# 6  https://www.pccomponentes.com/corsair-icue-h15...     188€        349,90€
# 7  https://www.pccomponentes.com/tempest-liquid-c...   56,59€         64,90€
# 8  https://www.pccomponentes.com/tempest-liquid-c...   59,99€         68,98€
# 9  https://www.pccomponentes.com/tempest-liquid-c...   35,59€         40,59€
#
#   rating       opiniones                      categoria
# 0  4,6/5  3187 opiniones  Kits de refrigeración líquida
# 1  4,6/5  3187 opiniones  Kits de refrigeración líquida
# 2  4,5/5   675 opiniones  Kits de refrigeración líquida
# 3  4,6/5    56 opiniones  Kits de refrigeración líquida
# 4  4,5/5    35 opiniones  Kits de refrigeración líquida
# 5  4,6/5   177 opiniones  Kits de refrigeración líquida
# 6  4,6/5    64 opiniones  Kits de refrigeración líquida
# 7  4,6/5  3187 opiniones  Kits de refrigeración líquida
# 8  4,6/5  3187 opiniones  Kits de refrigeración líquida
# 9  4,6/5  3187 opiniones  Kits de refrigeración líquida

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   producto_id     200 non-null    int64
#  1   timestamp       200 non-null    object
#  2   nombre          200 non-null    object
#  3   url             200 non-null    object
#  4   precio          200 non-null    object
#  5   precio_tachado  55 non-null     object
#  6   rating          167 non-null    object
#  7   opiniones       167 non-null    object
#  8   categoria       200 non-null    object
# dtypes: int64(1), object(8)
# memory usage: 14.2+ KB

# %%
df1['opiniones'] = df1['opiniones'].str.replace(r'\D', '', regex=True)
df1['opiniones'] = df1['opiniones'].fillna(0)
df1['opiniones'] = df1['opiniones'].astype(int)
df1.head()
# Out:
#    producto_id            timestamp  \
# 0            1  2025-02-18 12:32:30
# 1            2  2025-02-18 12:32:30
# 2            3  2025-02-18 12:32:30
# 3            4  2025-02-18 12:32:30
# 4            5  2025-02-18 12:32:30
#
#                                               nombre  \
# 0  Tempest Liquid Cooler 360 ARGB Kit de Refriger...
# 1  Tempest Liquid Cooler 360 Kit de Refrigeración...
# 2  Forgeon Azoth 240 ARGB Kit de Refrigeración Lí...
# 3  Nfortec ATRIA X Kit de Refrigeración Líquida 3...
# 4  Corsair NAUTILUS 360 RS ARGB Kit Refrigeración...
#
#                                                  url   precio precio_tachado  \
# 0  https://www.pccomponentes.com/tempest-liquid-c...   76,99€         87,99€
# 1  https://www.pccomponentes.com/tempest-liquid-c...   68,99€         78,98€
# 2  https://www.pccomponentes.com/forgeon-azoth-24...   75,99€        149,99€
# 3  https://www.pccomponentes.com/nfortec-atria-x-...   94,99€            NaN
# 4  https://www.pccomponentes.com/corsair-nautilus...  128,99€            NaN
#
#   rating  opiniones                      categoria
# 0  4,6/5       3187  Kits de refrigeración líquida
# 1  4,6/5       3187  Kits de refrigeración líquida
# 2  4,5/5        675  Kits de refrigeración líquida
# 3  4,6/5         56  Kits de refrigeración líquida
# 4  4,5/5         35  Kits de refrigeración líquida

# %%
df1['rating'] = df1['rating'].str.replace(',', '.', regex=False)
df1['rating'] = df1['rating'].str.replace(r'/5', '', regex=True)
df1['rating'] = df1['rating'].astype(float)
df1.head()
# Out:
#    producto_id            timestamp  \
# 0            1  2025-02-18 12:32:30
# 1            2  2025-02-18 12:32:30
# 2            3  2025-02-18 12:32:30
# 3            4  2025-02-18 12:32:30
# 4            5  2025-02-18 12:32:30
#
#                                               nombre  \
# 0  Tempest Liquid Cooler 360 ARGB Kit de Refriger...
# 1  Tempest Liquid Cooler 360 Kit de Refrigeración...
# 2  Forgeon Azoth 240 ARGB Kit de Refrigeración Lí...
# 3  Nfortec ATRIA X Kit de Refrigeración Líquida 3...
# 4  Corsair NAUTILUS 360 RS ARGB Kit Refrigeración...
#
#                                                  url   precio precio_tachado  \
# 0  https://www.pccomponentes.com/tempest-liquid-c...   76,99€         87,99€
# 1  https://www.pccomponentes.com/tempest-liquid-c...   68,99€         78,98€
# 2  https://www.pccomponentes.com/forgeon-azoth-24...   75,99€        149,99€
# 3  https://www.pccomponentes.com/nfortec-atria-x-...   94,99€            NaN
# 4  https://www.pccomponentes.com/corsair-nautilus...  128,99€            NaN
#
#    rating  opiniones                      categoria
# 0     4.6       3187  Kits de refrigeración líquida
# 1     4.6       3187  Kits de refrigeración líquida
# 2     4.5        675  Kits de refrigeración líquida
# 3     4.6         56  Kits de refrigeración líquida
# 4     4.5         35  Kits de refrigeración líquida

# %%
df1['precio'] = df1['precio'].str.replace('.', '', regex=False)
df1['precio'] = df1['precio'].str.replace(',', '.', regex=False)
df1['precio'] = df1['precio'].str.replace(r'€', '', regex=True)
df1['precio'] = df1['precio'].astype(float)
df1.head()
# Out:
#    producto_id            timestamp  \
# 0            1  2025-02-18 12:32:30
# 1            2  2025-02-18 12:32:30
# 2            3  2025-02-18 12:32:30
# 3            4  2025-02-18 12:32:30
# 4            5  2025-02-18 12:32:30
#
#                                               nombre  \
# 0  Tempest Liquid Cooler 360 ARGB Kit de Refriger...
# 1  Tempest Liquid Cooler 360 Kit de Refrigeración...
# 2  Forgeon Azoth 240 ARGB Kit de Refrigeración Lí...
# 3  Nfortec ATRIA X Kit de Refrigeración Líquida 3...
# 4  Corsair NAUTILUS 360 RS ARGB Kit Refrigeración...
#
#                                                  url  precio precio_tachado  \
# 0  https://www.pccomponentes.com/tempest-liquid-c...   76.99         87,99€
# 1  https://www.pccomponentes.com/tempest-liquid-c...   68.99         78,98€
# 2  https://www.pccomponentes.com/forgeon-azoth-24...   75.99        149,99€
# 3  https://www.pccomponentes.com/nfortec-atria-x-...   94.99            NaN
# 4  https://www.pccomponentes.com/corsair-nautilus...  128.99            NaN
#
#    rating  opiniones                      categoria
# 0     4.6       3187  Kits de refrigeración líquida
# 1     4.6       3187  Kits de refrigeración líquida
# 2     4.5        675  Kits de refrigeración líquida
# 3     4.6         56  Kits de refrigeración líquida
# 4     4.5         35  Kits de refrigeración líquida

# %%
df1['precio_tachado'] = df1['precio_tachado'].str.replace(',', '.', regex=False)
df1['precio_tachado'] = df1['precio_tachado'].str.replace(r'€', '', regex=True)
# df1['precio_tachado'] = df1['precio_tachado'].fillna(df1['precio'])
df1['precio_tachado'] = df1['precio_tachado'].astype(float)
df1.head()
# Out:
#    producto_id            timestamp  \
# 0            1  2025-02-18 12:32:30
# 1            2  2025-02-18 12:32:30
# 2            3  2025-02-18 12:32:30
# 3            4  2025-02-18 12:32:30
# 4            5  2025-02-18 12:32:30
#
#                                               nombre  \
# 0  Tempest Liquid Cooler 360 ARGB Kit de Refriger...
# 1  Tempest Liquid Cooler 360 Kit de Refrigeración...
# 2  Forgeon Azoth 240 ARGB Kit de Refrigeración Lí...
# 3  Nfortec ATRIA X Kit de Refrigeración Líquida 3...
# 4  Corsair NAUTILUS 360 RS ARGB Kit Refrigeración...
#
#                                                  url  precio  precio_tachado  \
# 0  https://www.pccomponentes.com/tempest-liquid-c...   76.99           87.99
# 1  https://www.pccomponentes.com/tempest-liquid-c...   68.99           78.98
# 2  https://www.pccomponentes.com/forgeon-azoth-24...   75.99          149.99
# 3  https://www.pccomponentes.com/nfortec-atria-x-...   94.99             NaN
# 4  https://www.pccomponentes.com/corsair-nautilus...  128.99             NaN
#
#    rating  opiniones                      categoria
# 0     4.6       3187  Kits de refrigeración líquida
# 1     4.6       3187  Kits de refrigeración líquida
# 2     4.5        675  Kits de refrigeración líquida
# 3     4.6         56  Kits de refrigeración líquida
# 4     4.5         35  Kits de refrigeración líquida

# %%
df1['timestamp'] = pd.to_datetime(df1['timestamp'])
df1.head()
# Out:
#    producto_id           timestamp  \
# 0            1 2025-02-18 12:32:30
# 1            2 2025-02-18 12:32:30
# 2            3 2025-02-18 12:32:30
# 3            4 2025-02-18 12:32:30
# 4            5 2025-02-18 12:32:30
#
#                                               nombre  \
# 0  Tempest Liquid Cooler 360 ARGB Kit de Refriger...
# 1  Tempest Liquid Cooler 360 Kit de Refrigeración...
# 2  Forgeon Azoth 240 ARGB Kit de Refrigeración Lí...
# 3  Nfortec ATRIA X Kit de Refrigeración Líquida 3...
# 4  Corsair NAUTILUS 360 RS ARGB Kit Refrigeración...
#
#                                                  url  precio  precio_tachado  \
# 0  https://www.pccomponentes.com/tempest-liquid-c...   76.99           87.99
# 1  https://www.pccomponentes.com/tempest-liquid-c...   68.99           78.98
# 2  https://www.pccomponentes.com/forgeon-azoth-24...   75.99          149.99
# 3  https://www.pccomponentes.com/nfortec-atria-x-...   94.99             NaN
# 4  https://www.pccomponentes.com/corsair-nautilus...  128.99             NaN
#
#    rating  opiniones                      categoria
# 0     4.6       3187  Kits de refrigeración líquida
# 1     4.6       3187  Kits de refrigeración líquida
# 2     4.5        675  Kits de refrigeración líquida
# 3     4.6         56  Kits de refrigeración líquida
# 4     4.5         35  Kits de refrigeración líquida

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   producto_id     200 non-null    int64
#  1   timestamp       200 non-null    datetime64[ns]
#  2   nombre          200 non-null    object
#  3   url             200 non-null    object
#  4   precio          200 non-null    float64
#  5   precio_tachado  55 non-null     float64
#  6   rating          167 non-null    float64
#  7   opiniones       200 non-null    int32
#  8   categoria       200 non-null    object
# dtypes: datetime64[ns](1), float64(3), int32(1), int64(1), object(3)
# memory usage: 13.4+ KB

# %%
df1.to_csv('productos_componentes_pc_limpio.csv', index=False)

# %%
df2 = pd.read_csv('caracteristicas_productos_componentes_pc.csv')
df2.head(10)
# Out:
#                                             Producto  \
# 0  NZXT Kraken Elite 360 RGB Kit de Refrigeración...
# 1  Forgeon Bolt PSU 1000W 80+ Gold Full Modular N...
# 2           SanDisk Extreme SSD Externo V2 4TB USB-C
# 3  Tempest Liquid Cooler 240 ARGB Kit Refrigeraci...
# 4  Forgeon Overmind Ventiladores Suplementarios I...
# 5  Corsair iCUE H100i RGB ELITE Kit de Refrigerac...
# 6        Crucial X9 SSD Disco Duro Externo 1TB USB-C
# 7  Corsair RM White Series RM750 750W 80 Plus Gol...
# 8  Tempest Liquid Cooler 360 RGB Kit de Refrigera...
# 9             Samsung T7 SSD 2TB USB 3.2 Gris Carbón
#
#                                     Característica_1  \
# 0  PERSONALIZACIÓN QUE DESTACA: Exhibe tu imagen ...
# 1                                     Ahorra espacio
# 2  Potente y portátil. Obtén el veloz rendimiento...
# 3  Enfría tu procesador: Olvida los viejos ventil...
# 4  Iluminación Atractiva: Los ventiladores Forgeo...
# 5  Refrigeración avanzada de CPU todo en uno: Ofr...
# 6  Aumente su almacenamiento. Olvídese de las cuo...
# 7  POTENCIA SILENCIOSA CON CERTIFICACIÓN GOLD: La...
# 8                     Compatibilidad con Intel y AMD
# 9  Transferencia al instante. Transfiere tus arch...
#
#                                     Característica_2  \
# 0  PANTALLA LCD CON GRAN ÁNGULO DE VISIÓN: Pantal...
# 1                                  Fácil instalación
# 2  Lo suficientemente resistente como para llevar...
# 3  Disfruta de su instalación: Referente a su ins...
# 4  Diseño modular: gracias a su conexión en forma...
# 5  Diseño de cabezal de bomba moderno con 16 LED ...
# 6  Compatibilidad plug-and-play. Con una sencilla...
# 7  DISPONIBLE EN BLANCO O NEGRO: ¿Lo suyo es más ...
# 8                                            Luz RGB
# 9  Construido de manera fuerte y segura. SSD sign...
#
#                                     Característica_3  \
# 0  BOMBA DE ALTO RENDIMIENTO: La potente bomba de...
# 1                        Mayor eficiencia energética
# 2  Viaja sin inconvenientes. Tendrás mayor tranqu...
# 3  Efectos impactantes: Gracias a su sistema de i...
# 4  Alto Rendimiento: Con velocidades ajustables e...
# 5  Rendimiento de refrigeración de vanguardia: Me...
# 6  Durabilidad sobre la marcha. A diferencia de l...
# 7  OPTIMIZADA PARA UN FUNCIONAMIENTO PRÁCTICAMENT...
# 8                                  Fácil Instalación
# 9  Estilo elegante y compacto. De bolsillo y fino...
#
#                                     Característica_4  \
# 0  REFRIGERACIÓN COLORIDA: Los ventiladores Core ...
# 1                      Mayor fiabilidad y protección
# 2  Va dondequiera que vayas. Utiliza el práctico ...
# 3  Compatibilidad y limpieza: En cuanto a compati...
# 4  Operación Silenciosa: A pesar de su rendimient...
# 5  Unifique su sistema: El potente software CORSA...
# 6  Haga copia de seguridad de todo lo que importa...
# 7  ALTA EFICIENCIA: Con una eficiencia máxima sup...
# 8  Enfría tu procesador: Olvida los viejos ventil...
# 9  Compatibilidad con varios dispositivos. Accede...
#
#                                     Característica_5  \
# 0  FÁCIL DE INSTALAR: Un único cable breakout con...
# 1                                   CABLES MODULARES
# 2  Asegura tus archivos. Mantén tu contenido priv...
# 3  Compatible:\r\n\r\nIntel:LGA 115x,1200,1700,20...
# 4       Velocidad del ventilador: 800-2000 RPM+/-10%
# 5  Modos de refrigeración especializados para un ...
# 6  Calidad, confianza y diseño práctico. Diseñada...
# 7  COMPLETAMENTE MODULAR, CON MÚLTIPLES CONECTORE...
# 8  Disfruta de su instalación: Referente a su ins...
# 9                            Unidad de estado sólido
#
#                                     Característica_6  \
# 0  TUBOS REFORZADOS: Los maguitos de nailon trenz...
# 1                    EFICIENCIA 80+ GOLD CERTIFICADA
# 2  Almacenamiento de calidad profesional. De SanD...
# 3         Intel:LGA 115x,1200,1700,2011,2011-v3,2066
# 4                         Nivel de ruido Max: 29 dBA
# 5  Placa refrigerante y bomba de alto rendimiento...
# 6                            Unidad de estado sólido
# 7  MODO DE VENTILADOR SIN REVOLUCIONES: A cargas ...
# 8  Modo overclocking: Desde su fabricación se ha ...
# 9                            SDD, capacidad: 2000 GB
#
#                                     Característica_7  \
# 0  COMPATIBILIDAD DE PROCESADOR: Incluye todas la...
# 1              100 % CAPACITADORES JAPONESES 105 ° C
# 2                            Unidad de estado sólido
# 3                     AMD: FM2/+,AM2/+,AM3/+,AM4,AM5
# 4                            Caudal de aire: 60.5CFM
# 5  Radiador de gran superficie: Un radiador de 24...
# 6                               SDD, capacidad: 1 TB
# 7  TECNOLOGÍA Y FIABILIDAD: Para lograr un rendim...
# 8  Compatibilidad y limpieza: En cuanto a compati...
# 9                                           NVMe: Si
#
#                                     Característica_8  \
# 0                                          Desempeño
# 1  PROTECCIONES CONTRA Sobrevoltaje (OVP), Cortoc...
# 2                            SDD, capacidad: 4000 GB
# 3                            Voltaje:  12V / 5V(LED)
# 4                         Presión del aire: 2 mm H2O
# 5  Instalación sencilla: Soporte de montaje modul...
# 6                                           NVMe: No
# 7  SU CONFIGURACIÓN, A SU GUSTO: Todas las fuente...
# 8  Soporte:\r\n\r\nIntel: Socket LGA 775/1155/115...
# 9                    Velocidad de lectura: 1050 MB/s
#
#                                     Característica_9  \
# 0                  Localización adecuada: Procesador
# 1                                 Modelo: BOLT 1000W
# 2                                           NVMe: Si
# 3                                 Ventiladores: 2PCS
# 4                Tensión nominal del ventilador: 12V
# 5  Dimensiones del Radiador (mm): 277 mm x 120 mm...
# 6                    Velocidad de lectura: 1050 MB/s
# 7                                 Control de energía
# 8  Intel: Socket LGA 775/1155/1156/1366/2011/1200...
# 9                  Velocidad de escritura: 1000 MB/s
#
#                                    Característica_10  \
# 0  Tipo: Sistema de refrigeración líquida todo en...
# 1                Dimensiones: 150mm  x 86mm  x 160mm
# 2                    Velocidad de lectura: 1050 MB/s
# 3                   Tamaño ventilador:  120*120*25mm
# 4             Corriente nominal del ventilador: 0.3A
# 5           Material de la placa refrigerante: Cobre
# 6                               SDD, capacidad: 1 TB
# 7                              Potencia total: 750 W
# 8  AMD: AM4 / FM2 / FM1 / AM3 + / AM3 / AM2 + / A...
# 9                            SDD, capacidad: 2000 GB
#
#                     Característica_11  \
# 0       Diámetro de ventilador: 12 cm
# 1                        Formato: ATX
# 2   Velocidad de escritura: 1000 MB/s
# 3      Tamaño radiador:  274*120*27mm
# 4             Tensión nominal LEF: 5V
# 5     Material del radiador: Aluminio
# 6                            NVMe: No
# 7  Voltaje de entrada AC: 100 - 240 V
# 8         Potencia de entrada: 3,84 W
# 9                            NVMe: Si
#
#                                    Característica_12  \
# 0  Sockets de procesador soportados: LGA 1150 (Zó...
# 1                                        Peso: 2,7Kg
# 2                            SDD, capacidad: 4000 GB
# 3                             Longitud tubo:   400mm
# 4                   Corriente nominal del LED: 0.75A
# 5  Ventiladores incluidos: 2 ventiladores AF120 E...
# 6                    Velocidad de lectura: 1050 MB/s
# 7               Frecuencia de entrada AC: 47 - 63 Hz
# 8             Ventilador: N.I.T PWM x 3 Ventiladores
# 9                    Velocidad de lectura: 1050 MB/s
#
#                                    Característica_13  \
# 0  Procesador compatible: AMD Ryzen™ 3, AMD Ryzen...
# 1  Puertos e interfaces\r\n\r\n1x Alimentador de ...
# 2                                           NVMe: Si
# 3  Diametro tubo:  \r\n\r\nDiámetro exterior Ø14m...
# 4  Tipo de rodamiento: Rodamiento hidráulico diná...
# 5     Velocidad máxima del ventilador: 400-1.850 RPM
# 6                               Puertos e Interfaces
# 7                     Corriente de entrada: 10 - 5 A
# 8              Tamaño ventiladores: 120x120x25 mm x3
# 9                  Velocidad de escritura: 1000 MB/s
#
#                                    Característica_14  \
# 0                    Máximo flujo de aire: 78,86 cfm
# 1  1x Alimentador de energía para placa base: 20+...
# 2                    Velocidad de lectura: 1050 MB/s
# 3                            Diámetro exterior Ø14mm
# 4                  Conector del ventilador: 4Pin PWM
# 5      Dimensiones del ventilador: 120 x 120 x 25 mm
# 6                           Conector USB: USB Tipo C
# 7                  Potencia combinada (3,3 V): 150 W
# 8                      Tamaño radiador: 395x120x27mm
# 9                               Puertos e Interfaces
#
#                                    Característica_15  \
# 0                 Presión máxima de aire: 2,57 mmH2O
# 1  2x Conector de energía EPS (8-pin), Longitud 7...
# 2                  Velocidad de escritura: 1000 MB/s
# 3                           Diámetro interior Ø5.8mm
# 4                   Conector RGB direccionable: 3Pin
# 5        Flujo de aire del ventilador: 10,8-59,1 CFM
# 6                 Versión USB: 3.2 Gen 2 (3.1 Gen 2)
# 7                  Potencia combinada (+12 V): 750 W
# 8                               Longitud tubo: 385mm
# 9                           Conector USB: USB Tipo C
#
#                                    Característica_16
# 0  Compatible con modulación por ancho de pulsos ...
# 1  4x Conectores de energía PCI Express (6 + 2 pi...
# 2                               Puertos e Interfaces
# 3                        Tamaño bomba:  78.5*70*54mm
# 4          Conector del ventilador principal: 4x7Pin
# 5  Presión estática del ventilador: 0,09-1,93 mm-H2O
# 6                  Tecnología Thunderbolt (Rayo): No
# 7                   Potencia combinada (+5 V): 150 W
# 8                              Diámetro tubo: 12.7mm
# 9                 Versión USB: 3.2 Gen 2 (3.1 Gen 2)

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 17 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Producto           10 non-null     object
#  1   Característica_1   10 non-null     object
#  2   Característica_2   10 non-null     object
#  3   Característica_3   10 non-null     object
#  4   Característica_4   10 non-null     object
#  5   Característica_5   10 non-null     object
#  6   Característica_6   10 non-null     object
#  7   Característica_7   10 non-null     object
#  8   Característica_8   10 non-null     object
#  9   Característica_9   10 non-null     object
#  10  Característica_10  10 non-null     object
#  11  Característica_11  10 non-null     object
#  12  Característica_12  10 non-null     object
#  13  Característica_13  10 non-null     object
#  14  Característica_14  10 non-null     object
#  15  Característica_15  10 non-null     object
#  16  Característica_16  10 non-null     object
# dtypes: object(17)
# memory usage: 1.5+ KB

# %%
column_names = {
    "Característica_1": "detalle_unico",
    "Característica_2": "pantalla",
    "Característica_3": "bomba",
    "Característica_4": "refrigeracion",
    "Característica_5": "instalacion",
    "Característica_6": "tubos_reforzados",
    "Característica_7": "compatibilidad_procesador",
    }

df2.rename(columns=column_names, inplace=True)
   
df2.head()
# Out:
#                                             Producto  \
# 0  NZXT Kraken Elite 360 RGB Kit de Refrigeración...
# 1  Forgeon Bolt PSU 1000W 80+ Gold Full Modular N...
# 2           SanDisk Extreme SSD Externo V2 4TB USB-C
# 3  Tempest Liquid Cooler 240 ARGB Kit Refrigeraci...
# 4  Forgeon Overmind Ventiladores Suplementarios I...
#
#                                        detalle_unico  \
# 0  PERSONALIZACIÓN QUE DESTACA: Exhibe tu imagen ...
# 1                                     Ahorra espacio
# 2  Potente y portátil. Obtén el veloz rendimiento...
# 3  Enfría tu procesador: Olvida los viejos ventil...
# 4  Iluminación Atractiva: Los ventiladores Forgeo...
#
#                                             pantalla  \
# 0  PANTALLA LCD CON GRAN ÁNGULO DE VISIÓN: Pantal...
# 1                                  Fácil instalación
# 2  Lo suficientemente resistente como para llevar...
# 3  Disfruta de su instalación: Referente a su ins...
# 4  Diseño modular: gracias a su conexión en forma...
#
#                                                bomba  \
# 0  BOMBA DE ALTO RENDIMIENTO: La potente bomba de...
# 1                        Mayor eficiencia energética
# 2  Viaja sin inconvenientes. Tendrás mayor tranqu...
# 3  Efectos impactantes: Gracias a su sistema de i...
# 4  Alto Rendimiento: Con velocidades ajustables e...
#
#                                        refrigeracion  \
# 0  REFRIGERACIÓN COLORIDA: Los ventiladores Core ...
# 1                      Mayor fiabilidad y protección
# 2  Va dondequiera que vayas. Utiliza el práctico ...
# 3  Compatibilidad y limpieza: En cuanto a compati...
# 4  Operación Silenciosa: A pesar de su rendimient...
#
#                                          instalacion  \
# 0  FÁCIL DE INSTALAR: Un único cable breakout con...
# 1                                   CABLES MODULARES
# 2  Asegura tus archivos. Mantén tu contenido priv...
# 3  Compatible:\r\n\r\nIntel:LGA 115x,1200,1700,20...
# 4       Velocidad del ventilador: 800-2000 RPM+/-10%
#
#                                     tubos_reforzados  \
# 0  TUBOS REFORZADOS: Los maguitos de nailon trenz...
# 1                    EFICIENCIA 80+ GOLD CERTIFICADA
# 2  Almacenamiento de calidad profesional. De SanD...
# 3         Intel:LGA 115x,1200,1700,2011,2011-v3,2066
# 4                         Nivel de ruido Max: 29 dBA
#
#                            compatibilidad_procesador  \
# 0  COMPATIBILIDAD DE PROCESADOR: Incluye todas la...
# 1              100 % CAPACITADORES JAPONESES 105 ° C
# 2                            Unidad de estado sólido
# 3                     AMD: FM2/+,AM2/+,AM3/+,AM4,AM5
# 4                            Caudal de aire: 60.5CFM
#
#                                     Característica_8  \
# 0                                          Desempeño
# 1  PROTECCIONES CONTRA Sobrevoltaje (OVP), Cortoc...
# 2                            SDD, capacidad: 4000 GB
# 3                            Voltaje:  12V / 5V(LED)
# 4                         Presión del aire: 2 mm H2O
#
#                       Característica_9  \
# 0    Localización adecuada: Procesador
# 1                   Modelo: BOLT 1000W
# 2                             NVMe: Si
# 3                   Ventiladores: 2PCS
# 4  Tensión nominal del ventilador: 12V
#
#                                    Característica_10  \
# 0  Tipo: Sistema de refrigeración líquida todo en...
# 1                Dimensiones: 150mm  x 86mm  x 160mm
# 2                    Velocidad de lectura: 1050 MB/s
# 3                   Tamaño ventilador:  120*120*25mm
# 4             Corriente nominal del ventilador: 0.3A
#
#                    Característica_11  \
# 0      Diámetro de ventilador: 12 cm
# 1                       Formato: ATX
# 2  Velocidad de escritura: 1000 MB/s
# 3     Tamaño radiador:  274*120*27mm
# 4            Tensión nominal LEF: 5V
#
#                                    Característica_12  \
# 0  Sockets de procesador soportados: LGA 1150 (Zó...
# 1                                        Peso: 2,7Kg
# 2                            SDD, capacidad: 4000 GB
# 3                             Longitud tubo:   400mm
# 4                   Corriente nominal del LED: 0.75A
#
#                                    Característica_13  \
# 0  Procesador compatible: AMD Ryzen™ 3, AMD Ryzen...
# 1  Puertos e interfaces\r\n\r\n1x Alimentador de ...
# 2                                           NVMe: Si
# 3  Diametro tubo:  \r\n\r\nDiámetro exterior Ø14m...
# 4  Tipo de rodamiento: Rodamiento hidráulico diná...
#
#                                    Característica_14  \
# 0                    Máximo flujo de aire: 78,86 cfm
# 1  1x Alimentador de energía para placa base: 20+...
# 2                    Velocidad de lectura: 1050 MB/s
# 3                            Diámetro exterior Ø14mm
# 4                  Conector del ventilador: 4Pin PWM
#
#                                    Característica_15  \
# 0                 Presión máxima de aire: 2,57 mmH2O
# 1  2x Conector de energía EPS (8-pin), Longitud 7...
# 2                  Velocidad de escritura: 1000 MB/s
# 3                           Diámetro interior Ø5.8mm
# 4                   Conector RGB direccionable: 3Pin
#
#                                    Característica_16
# 0  Compatible con modulación por ancho de pulsos ...
# 1  4x Conectores de energía PCI Express (6 + 2 pi...
# 2                               Puertos e Interfaces
# 3                        Tamaño bomba:  78.5*70*54mm
# 4          Conector del ventilador principal: 4x7Pin

# %%
df2['detalle_unico'] = df2['detalle_unico'].str.replace(r'PERSONALIZACIÓN QUE DESTACA:', '', regex=True)
df2['pantalla'] = df2['pantalla'].str.replace(r'PANTALLA LCD CON GRAN ÁNGULO DE VISIÓN:', '', regex=True)
df2['bomba'] = df2['bomba'].str.replace(r'\BOMBA DE ALTO RENDIMIENTO:', '', regex=True)
df2['refrigeracion'] = df2['refrigeracion'].str.replace(r'REFRIGERACIÓN COLORIDA:', '', regex=True)
df2['instalacion'] = df2['instalacion'].str.replace(r'FÁCIL DE INSTALAR:', '', regex=True)
df2['tubos_reforzados'] = df2['tubos_reforzados'].str.replace(r'TUBOS REFORZADOS:', '', regex=True)
df2['compatibilidad_procesador'] = df2['compatibilidad_procesador'].str.replace(r'COMPATIBILIDAD DE PROCESADOR:', '', regex=True)

df2.head()
# Out:
#                                             Producto  \
# 0  NZXT Kraken Elite 360 RGB Kit de Refrigeración...
# 1  Forgeon Bolt PSU 1000W 80+ Gold Full Modular N...
# 2           SanDisk Extreme SSD Externo V2 4TB USB-C
# 3  Tempest Liquid Cooler 240 ARGB Kit Refrigeraci...
# 4  Forgeon Overmind Ventiladores Suplementarios I...
#
#                                        detalle_unico  \
# 0   Exhibe tu imagen estática o GIF animado prefe...
# 1                                     Ahorra espacio
# 2  Potente y portátil. Obtén el veloz rendimiento...
# 3  Enfría tu procesador: Olvida los viejos ventil...
# 4  Iluminación Atractiva: Los ventiladores Forgeo...
#
#                                             pantalla  \
# 0   Pantalla LCD de 2,36” de diámetro con gran án...
# 1                                  Fácil instalación
# 2  Lo suficientemente resistente como para llevar...
# 3  Disfruta de su instalación: Referente a su ins...
# 4  Diseño modular: gracias a su conexión en forma...
#
#                                                bomba  \
# 0  B La potente bomba de Asetek cuenta con un mot...
# 1                        Mayor eficiencia energética
# 2  Viaja sin inconvenientes. Tendrás mayor tranqu...
# 3  Efectos impactantes: Gracias a su sistema de i...
# 4  Alto Rendimiento: Con velocidades ajustables e...
#
#                                        refrigeracion  \
# 0   Los ventiladores Core RGB con rodamientos din...
# 1                      Mayor fiabilidad y protección
# 2  Va dondequiera que vayas. Utiliza el práctico ...
# 3  Compatibilidad y limpieza: En cuanto a compati...
# 4  Operación Silenciosa: A pesar de su rendimient...
#
#                                          instalacion  \
# 0   Un único cable breakout conecta la bomba a la...
# 1                                   CABLES MODULARES
# 2  Asegura tus archivos. Mantén tu contenido priv...
# 3  Compatible:\r\n\r\nIntel:LGA 115x,1200,1700,20...
# 4       Velocidad del ventilador: 800-2000 RPM+/-10%
#
#                                     tubos_reforzados  \
# 0   Los maguitos de nailon trenzado protegen los ...
# 1                    EFICIENCIA 80+ GOLD CERTIFICADA
# 2  Almacenamiento de calidad profesional. De SanD...
# 3         Intel:LGA 115x,1200,1700,2011,2011-v3,2066
# 4                         Nivel de ruido Max: 29 dBA
#
#                            compatibilidad_procesador  \
# 0   Incluye todas las herramientas de montaje nec...
# 1              100 % CAPACITADORES JAPONESES 105 ° C
# 2                            Unidad de estado sólido
# 3                     AMD: FM2/+,AM2/+,AM3/+,AM4,AM5
# 4                            Caudal de aire: 60.5CFM
#
#                                     Característica_8  \
# 0                                          Desempeño
# 1  PROTECCIONES CONTRA Sobrevoltaje (OVP), Cortoc...
# 2                            SDD, capacidad: 4000 GB
# 3                            Voltaje:  12V / 5V(LED)
# 4                         Presión del aire: 2 mm H2O
#
#                       Característica_9  \
# 0    Localización adecuada: Procesador
# 1                   Modelo: BOLT 1000W
# 2                             NVMe: Si
# 3                   Ventiladores: 2PCS
# 4  Tensión nominal del ventilador: 12V
#
#                                    Característica_10  \
# 0  Tipo: Sistema de refrigeración líquida todo en...
# 1                Dimensiones: 150mm  x 86mm  x 160mm
# 2                    Velocidad de lectura: 1050 MB/s
# 3                   Tamaño ventilador:  120*120*25mm
# 4             Corriente nominal del ventilador: 0.3A
#
#                    Característica_11  \
# 0      Diámetro de ventilador: 12 cm
# 1                       Formato: ATX
# 2  Velocidad de escritura: 1000 MB/s
# 3     Tamaño radiador:  274*120*27mm
# 4            Tensión nominal LEF: 5V
#
#                                    Característica_12  \
# 0  Sockets de procesador soportados: LGA 1150 (Zó...
# 1                                        Peso: 2,7Kg
# 2                            SDD, capacidad: 4000 GB
# 3                             Longitud tubo:   400mm
# 4                   Corriente nominal del LED: 0.75A
#
#                                    Característica_13  \
# 0  Procesador compatible: AMD Ryzen™ 3, AMD Ryzen...
# 1  Puertos e interfaces\r\n\r\n1x Alimentador de ...
# 2                                           NVMe: Si
# 3  Diametro tubo:  \r\n\r\nDiámetro exterior Ø14m...
# 4  Tipo de rodamiento: Rodamiento hidráulico diná...
#
#                                    Característica_14  \
# 0                    Máximo flujo de aire: 78,86 cfm
# 1  1x Alimentador de energía para placa base: 20+...
# 2                    Velocidad de lectura: 1050 MB/s
# 3                            Diámetro exterior Ø14mm
# 4                  Conector del ventilador: 4Pin PWM
#
#                                    Característica_15  \
# 0                 Presión máxima de aire: 2,57 mmH2O
# 1  2x Conector de energía EPS (8-pin), Longitud 7...
# 2                  Velocidad de escritura: 1000 MB/s
# 3                           Diámetro interior Ø5.8mm
# 4                   Conector RGB direccionable: 3Pin
#
#                                    Característica_16
# 0  Compatible con modulación por ancho de pulsos ...
# 1  4x Conectores de energía PCI Express (6 + 2 pi...
# 2                               Puertos e Interfaces
# 3                        Tamaño bomba:  78.5*70*54mm
# 4          Conector del ventilador principal: 4x7Pin

# %%
df2 = df2.drop(['Característica_8','Característica_9','Característica_10', 
               'Característica_11','Característica_12','Característica_13',
               'Característica_14','Característica_15','Característica_16'], axis=1)

df2.head()
# Out:
#                                             Producto  \
# 0  NZXT Kraken Elite 360 RGB Kit de Refrigeración...
# 1  Forgeon Bolt PSU 1000W 80+ Gold Full Modular N...
# 2           SanDisk Extreme SSD Externo V2 4TB USB-C
# 3  Tempest Liquid Cooler 240 ARGB Kit Refrigeraci...
# 4  Forgeon Overmind Ventiladores Suplementarios I...
#
#                                        detalle_unico  \
# 0   Exhibe tu imagen estática o GIF animado prefe...
# 1                                     Ahorra espacio
# 2  Potente y portátil. Obtén el veloz rendimiento...
# 3  Enfría tu procesador: Olvida los viejos ventil...
# 4  Iluminación Atractiva: Los ventiladores Forgeo...
#
#                                             pantalla  \
# 0   Pantalla LCD de 2,36” de diámetro con gran án...
# 1                                  Fácil instalación
# 2  Lo suficientemente resistente como para llevar...
# 3  Disfruta de su instalación: Referente a su ins...
# 4  Diseño modular: gracias a su conexión en forma...
#
#                                                bomba  \
# 0  B La potente bomba de Asetek cuenta con un mot...
# 1                        Mayor eficiencia energética
# 2  Viaja sin inconvenientes. Tendrás mayor tranqu...
# 3  Efectos impactantes: Gracias a su sistema de i...
# 4  Alto Rendimiento: Con velocidades ajustables e...
#
#                                        refrigeracion  \
# 0   Los ventiladores Core RGB con rodamientos din...
# 1                      Mayor fiabilidad y protección
# 2  Va dondequiera que vayas. Utiliza el práctico ...
# 3  Compatibilidad y limpieza: En cuanto a compati...
# 4  Operación Silenciosa: A pesar de su rendimient...
#
#                                          instalacion  \
# 0   Un único cable breakout conecta la bomba a la...
# 1                                   CABLES MODULARES
# 2  Asegura tus archivos. Mantén tu contenido priv...
# 3  Compatible:\r\n\r\nIntel:LGA 115x,1200,1700,20...
# 4       Velocidad del ventilador: 800-2000 RPM+/-10%
#
#                                     tubos_reforzados  \
# 0   Los maguitos de nailon trenzado protegen los ...
# 1                    EFICIENCIA 80+ GOLD CERTIFICADA
# 2  Almacenamiento de calidad profesional. De SanD...
# 3         Intel:LGA 115x,1200,1700,2011,2011-v3,2066
# 4                         Nivel de ruido Max: 29 dBA
#
#                            compatibilidad_procesador
# 0   Incluye todas las herramientas de montaje nec...
# 1              100 % CAPACITADORES JAPONESES 105 ° C
# 2                            Unidad de estado sólido
# 3                     AMD: FM2/+,AM2/+,AM3/+,AM4,AM5
# 4                            Caudal de aire: 60.5CFM

# %%
df2["Producto"][0]
# Out:
# 'NZXT Kraken Elite 360 RGB Kit de Refrigeración Líquida'
