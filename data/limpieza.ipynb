# %%
import pandas as pd

# %%
df = pd.read_csv('productos_portatiles_actualizado.csv')
df.head(10)
# Out:
#    producto_id            timestamp  \
# 0            1  2025-02-28 08:40:09
# 1            2  2025-02-28 08:40:24
# 2            3  2025-02-28 08:40:41
# 3            4  2025-02-28 08:40:57
# 4            5  2025-02-28 08:41:11
# 5            6  2025-02-28 08:41:25
# 6            7  2025-02-28 08:41:40
# 7            8  2025-02-28 08:41:55
# 8            9  2025-02-28 08:42:13
# 9           10  2025-02-28 08:42:29
#
#                                               nombre  \
# 0  Acer TravelMate P2 TMP214-55-TCO-51RL Intel Co...
# 1  Portátil Acer TravelMate P2 TMP215-54-584F Int...
# 2  Acer TravelMate P2 TMP215-54-71UZ Intel Core i...
# 3  Acer TravelMate P2 TMP216-51-TCO-346K Netbook ...
# 4  Acer TravelMate P2 TMP216-51-TCO-5584 Intel Co...
# 5  Acer TravelMate P2 TMP216-51-TCO-73AZ Intel Co...
# 6  Portátil Acer TravelMate P4 TMP414-53-G2-TCO-5...
# 7  Portátil Acer TravelMate TMP614-53-TCO-54RF In...
# 8  Portátil Acer Travelmate P4 TMP414-41R9F4 AMD ...
# ...

# %%
df.describe()
# Out:
#        producto_id  categoria_id
# count  1152.000000   1152.000000
# mean    576.500000      3.300347
# std     332.698061      2.518753
# min       1.000000      1.000000
# 25%     288.750000      1.000000
# 50%     576.500000      2.000000
# 75%     864.250000      4.000000
# max    1152.000000     10.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1152 entries, 0 to 1151
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   producto_id     1152 non-null   int64
#  1   timestamp       1152 non-null   object
#  2   nombre          1152 non-null   object
#  3   url             1152 non-null   object
#  4   precio          1152 non-null   object
#  5   precio_tachado  1152 non-null   object
#  6   rating          1152 non-null   object
#  7   opiniones       1152 non-null   object
#  8   categoria_id    1152 non-null   int64
# dtypes: int64(2), object(7)
# memory usage: 81.1+ KB

# %%
df["nombre"] = df["nombre"].astype(str)
df["url"] = df["url"].astype(str)
df["categoria_id"] = df["categoria_id"].astype(str)

# %%
df['opiniones'] = df['opiniones'].str.replace(r'\D', '', regex=True)
df['opiniones'] = df['opiniones'].fillna(0)
df['opiniones'] = df['opiniones'].astype(int)
df.head()
# Out:
#    producto_id            timestamp  \
# 0            1  2025-02-28 08:40:09
# 1            2  2025-02-28 08:40:24
# 2            3  2025-02-28 08:40:41
# 3            4  2025-02-28 08:40:57
# 4            5  2025-02-28 08:41:11
#
#                                               nombre  \
# 0  Acer TravelMate P2 TMP214-55-TCO-51RL Intel Co...
# 1  Portátil Acer TravelMate P2 TMP215-54-584F Int...
# 2  Acer TravelMate P2 TMP215-54-71UZ Intel Core i...
# 3  Acer TravelMate P2 TMP216-51-TCO-346K Netbook ...
# 4  Acer TravelMate P2 TMP216-51-TCO-5584 Intel Co...
#
#                                                  url   precio precio_tachado  \
# 0  https://www.pccomponentes.com/acer-travelmate-...  758,98€              0
# 1  https://www.pccomponentes.com/portatil-acer-tr...  728,79€              0
# 2  https://www.pccomponentes.com/acer-travelmate-...  912,04€              0
# 3  https://www.pccomponentes.com/acer-travelmate-...  769,60€              0
# ...

# %%
df['rating'] = df['rating'].str.replace(',', '.', regex=False)
df['rating'] = df['rating'].str.replace(r'/5', '', regex=True)
df['rating'] = df['rating'].astype(float)

# %%
df['precio'] = df['precio'].str.replace('.', '', regex=False)
df['precio'] = df['precio'].str.replace(',', '.', regex=False)
df['precio'] = df['precio'].str.replace(r'€', '', regex=True)
df['precio'] = df['precio'].astype(float)

# %%
df.head()
# Out:
#    producto_id            timestamp  \
# 0            1  2025-02-28 08:40:09
# 1            2  2025-02-28 08:40:24
# 2            3  2025-02-28 08:40:41
# 3            4  2025-02-28 08:40:57
# 4            5  2025-02-28 08:41:11
#
#                                               nombre  \
# 0  Acer TravelMate P2 TMP214-55-TCO-51RL Intel Co...
# 1  Portátil Acer TravelMate P2 TMP215-54-584F Int...
# 2  Acer TravelMate P2 TMP215-54-71UZ Intel Core i...
# 3  Acer TravelMate P2 TMP216-51-TCO-346K Netbook ...
# 4  Acer TravelMate P2 TMP216-51-TCO-5584 Intel Co...
#
#                                                  url  precio precio_tachado  \
# 0  https://www.pccomponentes.com/acer-travelmate-...  758.98              0
# 1  https://www.pccomponentes.com/portatil-acer-tr...  728.79              0
# 2  https://www.pccomponentes.com/acer-travelmate-...  912.04              0
# 3  https://www.pccomponentes.com/acer-travelmate-...  769.60              0
# ...

# %%
df['precio_tachado'] = df['precio_tachado'].str.replace('.', '', regex=False)
df['precio_tachado'] = df['precio_tachado'].str.replace(',', '.', regex=False)
df['precio_tachado'] = df['precio_tachado'].str.replace(r'€', '', regex=True)
# df['precio_tachado'] = df['precio_tachado'].fillna(df['precio'])
df['precio_tachado'] = df['precio_tachado'].astype(float)
df.head()
# Out:
#    producto_id            timestamp  \
# 0            1  2025-02-28 08:40:09
# 1            2  2025-02-28 08:40:24
# 2            3  2025-02-28 08:40:41
# 3            4  2025-02-28 08:40:57
# 4            5  2025-02-28 08:41:11
#
#                                               nombre  \
# 0  Acer TravelMate P2 TMP214-55-TCO-51RL Intel Co...
# 1  Portátil Acer TravelMate P2 TMP215-54-584F Int...
# 2  Acer TravelMate P2 TMP215-54-71UZ Intel Core i...
# 3  Acer TravelMate P2 TMP216-51-TCO-346K Netbook ...
# 4  Acer TravelMate P2 TMP216-51-TCO-5584 Intel Co...
#
#                                                  url  precio  precio_tachado  \
# 0  https://www.pccomponentes.com/acer-travelmate-...  758.98             0.0
# 1  https://www.pccomponentes.com/portatil-acer-tr...  728.79             0.0
# 2  https://www.pccomponentes.com/acer-travelmate-...  912.04             0.0
# 3  https://www.pccomponentes.com/acer-travelmate-...  769.60             0.0
# ...

# %%
df['timestamp'] = pd.to_datetime(df['timestamp'])

# %%
df.head(5)
# Out:
#    producto_id           timestamp  \
# 0            1 2025-02-28 08:40:09
# 1            2 2025-02-28 08:40:24
# 2            3 2025-02-28 08:40:41
# 3            4 2025-02-28 08:40:57
# 4            5 2025-02-28 08:41:11
#
#                                               nombre  \
# 0  Acer TravelMate P2 TMP214-55-TCO-51RL Intel Co...
# 1  Portátil Acer TravelMate P2 TMP215-54-584F Int...
# 2  Acer TravelMate P2 TMP215-54-71UZ Intel Core i...
# 3  Acer TravelMate P2 TMP216-51-TCO-346K Netbook ...
# 4  Acer TravelMate P2 TMP216-51-TCO-5584 Intel Co...
#
#                                                  url  precio  precio_tachado  \
# 0  https://www.pccomponentes.com/acer-travelmate-...  758.98             0.0
# 1  https://www.pccomponentes.com/portatil-acer-tr...  728.79             0.0
# 2  https://www.pccomponentes.com/acer-travelmate-...  912.04             0.0
# 3  https://www.pccomponentes.com/acer-travelmate-...  769.60             0.0
# ...

# %%
df.to_csv('productosPortatil-limpio.csv', index=False)

# %%
# 📌 Verificar que la columna de precio existe
if "precio" not in df.columns:
    print("❌ Error: La columna 'precio' no existe en el dataset.")
else:
    # 🔍 Revisar estadísticas generales de los precios
    print("📊 Estadísticas generales de precios:")
    print(df["precio"].describe())

    # 📌 Filtrar precios extremadamente bajos (Ejemplo: < 50€) o precios inusualmente altos (> 10,000€)
    precios_erroneos = df[(df["precio"] < 50) | (df["precio"] > 10000)]

    # 📌 Mostrar los datos erróneos
    if not precios_erroneos.empty:
        print("\n⚠️ Posibles errores detectados en los precios:")
        display(precios_erroneos)
    else:
        print("\n✅ No se encontraron precios sospechosos.")
# Out:
# 📊 Estadísticas generales de precios:
# count    1152.000000
# mean     1017.210252
# std       842.969907
# min         0.000000
# 25%       494.000000
# 50%       799.000000
# 75%      1399.000000
# max      6098.000000
# Name: precio, dtype: float64
#
# ⚠️ Posibles errores detectados en los precios:
#       producto_id           timestamp  \
# 81             82 2025-02-28 09:02:07
# 89             90 2025-02-28 09:04:08
# 91             92 2025-02-28 09:04:37
# 97             98 2025-02-28 09:06:07
# 111           112 2025-02-28 09:09:47
# ...           ...                 ...
# 1117         1118 2025-02-28 13:38:11
# 1122         1123 2025-02-28 13:39:22
# 1128         1129 2025-02-28 13:40:52
# 1129         1130 2025-02-28 13:41:09
# 1133         1134 2025-02-28 13:42:07
#
#                                                  nombre  \
# 81                                          Desconocido
# 89                                          Desconocido
# ...

# %%
print(df[df["producto_id"]== 105])
# Out:
#      producto_id           timestamp  \
# 104          105 2025-02-28 09:07:57
#
#                                                 nombre  \
# 104  Apple MacBook Pro Apple M2 Max/32GB/1TB SSD/14...
#
#                                                    url  precio  \
# 104  https://www.pccomponentes.com/apple-macbook-pr...  2750.0
#
#      precio_tachado  rating  opiniones categoria_id
# 104             0.0     4.9          1            6

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1152 entries, 0 to 1151
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   producto_id     1152 non-null   int64
#  1   timestamp       1152 non-null   datetime64[ns]
#  2   nombre          1152 non-null   object
#  3   url             1152 non-null   object
#  4   precio          1152 non-null   float64
#  5   precio_tachado  1152 non-null   float64
#  6   rating          1152 non-null   float64
#  7   opiniones       1152 non-null   int32
#  8   categoria_id    1152 non-null   object
# dtypes: datetime64[ns](1), float64(3), int32(1), int64(1), object(3)
# memory usage: 76.6+ KB
